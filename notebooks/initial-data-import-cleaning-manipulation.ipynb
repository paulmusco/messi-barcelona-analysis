# %%
import pandas as pd
import numpy as np
import os
pd.options.display.max_columns = None

# %% [markdown]
# # 1) 'competitions' data

# %%
competitions = pd.read_json('../data/original-data/competitions.json', orient='records')

# %%
competitions.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender season_name               match_updated   match_available
# 0               male   2018/2019            2020-07-29T05:00  2020-07-29T05:00
# 1               male   2017/2018            2020-07-29T05:00  2020-07-29T05:00
# 2               male   2016/2017  2020-08-26T12:33:15.869622  2020-07-29T05:00
# 3               male   2015/2016  2020-08-26T12:33:15.869622  2020-07-29T05:00
# 4               male   2014/2015  2020-08-26T12:33:15.869622  2020-07-29T05:00

# %%
competitions.dtypes
# Out:
# competition_id         int64
# season_id              int64
# country_name          object
# competition_name      object
# competition_gender    object
# season_name           object
# match_updated         object
# match_available       object
# dtype: object

# %% [markdown]
# The data types for 'match_updated' & 'match_available' should probably be datetime, but I won't be using those. In fact, I'll go ahead and drop all the columns I don't need...

# %%
selected_competitions = competitions[['competition_id', 'season_id', 'competition_name', 'season_name']]

# %%
selected_competitions.groupby('competition_name').count()
# Out:
#                          competition_id  season_id  season_name
# competition_name
# Champions League                     15         15           15
# FA Women's Super League               3          3            3
# FIFA World Cup                        1          1            1
# La Liga                              16         16           16
# NWSL                                  1          1            1
# Premier League                        1          1            1
# Women's World Cup                     1          1            1

# %% [markdown]
# I'll only be looking at La Liga & Champions League games, so can drop records that belong to all the other competitions.

# %%
selected_competitions = selected_competitions.drop(selected_competitions[(
    selected_competitions['competition_name'] != 'Champions League') & 
    (selected_competitions['competition_name'] != 'La Liga')].index)

# %% [markdown]
# Lionel Messi signed his first professional contract on 24th June 2005, I can delete any seasons prior to 2005/06.

# %%
selected_competitions = selected_competitions.drop(selected_competitions[(
    selected_competitions['season_name'] == '1999/2000') | 
    (selected_competitions['season_name'] == '2003/2004') | 
    (selected_competitions['season_name'] == '2004/2005')].index)

# %%
selected_competitions
# Out:
#     competition_id  season_id  competition_name season_name
# 0               16          4  Champions League   2018/2019
# 1               16          1  Champions League   2017/2018
# 2               16          2  Champions League   2016/2017
# 3               16         27  Champions League   2015/2016
# 4               16         26  Champions League   2014/2015
# 5               16         25  Champions League   2013/2014
# 6               16         24  Champions League   2012/2013
# 7               16         23  Champions League   2011/2012
# 8               16         22  Champions League   2010/2011
# 9               16         21  Champions League   2009/2010
# 10              16         41  Champions League   2008/2009
# 11              16         39  Champions League   2006/2007
# 19              11         42           La Liga   2019/2020
# 20              11          4           La Liga   2018/2019
# 21              11          1           La Liga   2017/2018
# 22              11          2           La Liga   2016/2017
# 23              11         27           La Liga   2015/2016
# 24              11         26           La Liga   2014/2015
# 25              11         25           La Liga   2013/2014
# 26              11         24           La Liga   2012/2013
# 27              11         23           La Liga   2011/2012
# 28              11         22           La Liga   2010/2011
# 29              11         21           La Liga   2009/2010
# 30              11         41           La Liga   2008/2009
# 31              11         40           La Liga   2007/2008
# 32              11         39           La Liga   2006/2007
# 33              11         38           La Liga   2005/2006

# %% [markdown]
# There appears to be missing data for the 2005/06, 2007/08 & 2019/20 Champions League competitions, this is something I'll need to consider if comparing La Liga performance v Champions League performance at a later stage.

# %% [markdown]
# I may require the unique values from the 'competition_id' & 'season_id' columns when importing the 'matches' data, so will create those lists now...

# %%
competition_codes = list(selected_competitions['competition_id'].unique())
season_codes = list(selected_competitions['season_id'].unique())

# %%
competition_codes
# Out:
# [16, 11]

# %%
season_codes
# Out:
# [4, 1, 2, 27, 26, 25, 24, 23, 22, 21, 41, 39, 42, 40, 38]

# %% [markdown]
# # 2) 'matches' data

# %% [markdown]
# Import and combine multiple JSON files into a single dataframe using the La Liga competition code.

# %%
laliga_base_dir = r'C:\Users\paul_\Desktop\Ironhack\course-work\projects\ironhack-final-project\data\original-data\matches\11'

laliga_match_list = []
for file in os.listdir(laliga_base_dir):
    json_path = os.path.join(laliga_base_dir, file)
    json_data = pd.read_json(json_path, orient='records')
    laliga_match_list.append(json_data)
laliga_matches = pd.concat(laliga_match_list, axis=0, ignore_index=True)

# %%
laliga_matches
# Out:
#      match_id  match_date      kick_off  \
# 0        9592  2017-09-09  20:45:00.000
# 1        9870  2018-04-07  20:45:00.000
# 2        9783  2018-02-04  16:15:00.000
# 3        9609  2017-09-19  22:00:00.000
# 4        9700  2017-12-02  13:00:00.000
# ..        ...         ...           ...
# 480    303524  2019-12-01  21:00:00.000
# 481    303451  2019-12-07  21:00:00.000
# 482    303517  2019-12-21  16:00:00.000
# 483    303682  2020-02-02  21:00:00.000
# 484    303731  2020-02-22  16:00:00.000
#
#                                            competition  \
# 0    {'competition_id': 11, 'country_name': 'Spain'...
# 1    {'competition_id': 11, 'country_name': 'Spain'...
# 2    {'competition_id': 11, 'country_name': 'Spain'...
# 3    {'competition_id': 11, 'country_name': 'Spain'...
# 4    {'competition_id': 11, 'country_name': 'Spain'...
# ..                                                 ...
# 480  {'competition_id': 11, 'country_name': 'Spain'...
# 481  {'competition_id': 11, 'country_name': 'Spain'...
# 482  {'competition_id': 11, 'country_name': 'Spain'...
# 483  {'competition_id': 11, 'country_name': 'Spain'...
# 484  {'competition_id': 11, 'country_name': 'Spain'...
#
#                                             season  \
# 0     {'season_id': 1, 'season_name': '2017/2018'}
# 1     {'season_id': 1, 'season_name': '2017/2018'}
# 2     {'season_id': 1, 'season_name': '2017/2018'}
# 3     {'season_id': 1, 'season_name': '2017/2018'}
# 4     {'season_id': 1, 'season_name': '2017/2018'}
# ..                                             ...
# 480  {'season_id': 42, 'season_name': '2019/2020'}
# 481  {'season_id': 42, 'season_name': '2019/2020'}
# 482  {'season_id': 42, 'season_name': '2019/2020'}
# 483  {'season_id': 42, 'season_name': '2019/2020'}
# 484  {'season_id': 42, 'season_name': '2019/2020'}
#
#                                              home_team  \
# 0    {'home_team_id': 217, 'home_team_name': 'Barce...
# 1    {'home_team_id': 217, 'home_team_name': 'Barce...
# 2    {'home_team_id': 214, 'home_team_name': 'Espan...
# 3    {'home_team_id': 217, 'home_team_name': 'Barce...
# 4    {'home_team_id': 217, 'home_team_name': 'Barce...
# ..                                                 ...
# 480  {'home_team_id': 212, 'home_team_name': 'Atlét...
# 481  {'home_team_id': 217, 'home_team_name': 'Barce...
# 482  {'home_team_id': 217, 'home_team_name': 'Barce...
# 483  {'home_team_id': 217, 'home_team_name': 'Barce...
# 484  {'home_team_id': 217, 'home_team_name': 'Barce...
#
#                                              away_team  home_score  \
# 0    {'away_team_id': 214, 'away_team_name': 'Espan...           5
# 1    {'away_team_id': 205, 'away_team_name': 'Legan...           3
# 2    {'away_team_id': 217, 'away_team_name': 'Barce...           1
# 3    {'away_team_id': 322, 'away_team_name': 'Eibar...           6
# 4    {'away_team_id': 209, 'away_team_name': 'Celta...           2
# ..                                                 ...         ...
# 480  {'away_team_id': 217, 'away_team_name': 'Barce...           0
# 481  {'away_team_id': 1043, 'away_team_name': 'Mall...           5
# 482  {'away_team_id': 206, 'away_team_name': 'Depor...           4
# 483  {'away_team_id': 221, 'away_team_name': 'Levan...           2
# 484  {'away_team_id': 322, 'away_team_name': 'Eibar...           5
#
#      away_score match_status      last_updated  \
# 0             0    available  2020-07-29T05:00
# 1             1    available  2020-07-29T05:00
# 2             1    available  2020-07-29T05:00
# 3             1    available  2020-07-29T05:00
# 4             2    available  2020-07-29T05:00
# ..          ...          ...               ...
# 480           1    available  2020-07-29T05:00
# 481           2    available  2020-07-29T05:00
# 482           1    available  2020-07-29T05:00
# 483           1    available  2020-07-29T05:00
# 484           0    available  2020-07-29T05:00
#
#                                               metadata  match_week  \
# 0    {'data_version': '1.1.0', 'shot_fidelity_versi...           3
# 1    {'data_version': '1.0.2', 'shot_fidelity_versi...          31
# 2    {'data_version': '1.0.2', 'shot_fidelity_versi...          22
# 3    {'data_version': '1.0.2', 'shot_fidelity_versi...           5
# 4    {'data_version': '1.0.2', 'shot_fidelity_versi...          14
# ..                                                 ...         ...
# 480  {'data_version': '1.1.0', 'shot_fidelity_versi...          15
# 481  {'data_version': '1.1.0', 'shot_fidelity_versi...          16
# 482  {'data_version': '1.1.0', 'shot_fidelity_versi...          18
# 483  {'data_version': '1.1.0', 'shot_fidelity_versi...          22
# 484  {'data_version': '1.1.0', 'shot_fidelity_versi...          25
#
#                        competition_stage  \
# 0    {'id': 1, 'name': 'Regular Season'}
# 1    {'id': 1, 'name': 'Regular Season'}
# 2    {'id': 1, 'name': 'Regular Season'}
# 3    {'id': 1, 'name': 'Regular Season'}
# 4    {'id': 1, 'name': 'Regular Season'}
# ..                                   ...
# 480  {'id': 1, 'name': 'Regular Season'}
# 481  {'id': 1, 'name': 'Regular Season'}
# 482  {'id': 1, 'name': 'Regular Season'}
# 483  {'id': 1, 'name': 'Regular Season'}
# 484  {'id': 1, 'name': 'Regular Season'}
#
#                                                stadium  \
# 0    {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 1    {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 2    {'id': 351, 'name': 'RCDE Stadium', 'country':...
# 3    {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 4    {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# ..                                                 ...
# 480  {'id': 4654, 'name': 'Estadio Wanda Metropolit...
# 481  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 482  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 483  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 484  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
#
#                                                referee
# 0    {'id': 183, 'name': 'Jesús Gil', 'country': {'...
# 1    {'id': 215, 'name': 'Ricardo De Burgos', 'coun...
# 2    {'id': 183, 'name': 'Jesús Gil', 'country': {'...
# 3    {'id': 208, 'name': 'Alejandro Hernández', 'co...
# 4    {'id': 209, 'name': 'Mario Melero', 'country':...
# ..                                                 ...
# 480  {'id': 180, 'name': 'Antonio Mateu', 'country'...
# 481  {'id': 224, 'name': 'José Munuera', 'country':...
# 482  {'id': 209, 'name': 'Mario Melero', 'country':...
# 483  {'id': 492, 'name': 'Adrián Cordero', 'country...
# 484                  {'id': 874, 'name': 'César Soto'}
#
# [485 rows x 16 columns]

# %% [markdown]
# Import and combine multiple JSON files into a single dataframe using the Champions League competition code.

# %%
champsleague_base_dir = r'C:\Users\paul_\Desktop\Ironhack\course-work\projects\ironhack-final-project\data\original-data\matches\16'

champsleague_match_list = []
for file in os.listdir(champsleague_base_dir):
    json_path = os.path.join(champsleague_base_dir, file)
    json_data = pd.read_json(json_path, orient='records')
    champsleague_match_list.append(json_data)
champsleague_matches = pd.concat(champsleague_match_list, axis=0, ignore_index=True)

# %%
champsleague_matches
# Out:
#     match_id  match_date      kick_off  \
# 0      18245  2018-05-26  20:45:00.000
# 1      18244  2017-06-03  20:45:00.000
# 2      18235  2010-05-22  20:45:00.000
# 3      18236  2011-05-28  20:45:00.000
# 4      18237  2012-05-19  20:45:00.000
# 5      18240  2013-05-25  20:45:00.000
# 6      18241  2014-05-24  20:45:00.000
# 7      18242  2015-06-06  20:45:00.000
# 8      18243  2016-05-28  20:45:00.000
# 9    2302764  2005-05-25           NaN
# 10   3750200  2007-05-23  20:45:00.000
# 11     22912  2019-06-01  21:00:00.000
# 12   3750201  2009-05-27  20:45:00.000
# 13   3752619  2004-05-26           NaN
#
#                                           competition  \
# 0   {'competition_id': 16, 'country_name': 'Europe...
# 1   {'competition_id': 16, 'country_name': 'Europe...
# 2   {'competition_id': 16, 'country_name': 'Europe...
# 3   {'competition_id': 16, 'country_name': 'Europe...
# 4   {'competition_id': 16, 'country_name': 'Europe...
# 5   {'competition_id': 16, 'country_name': 'Europe...
# 6   {'competition_id': 16, 'country_name': 'Europe...
# 7   {'competition_id': 16, 'country_name': 'Europe...
# 8   {'competition_id': 16, 'country_name': 'Europe...
# 9   {'competition_id': 16, 'country_name': 'Europe...
# 10  {'competition_id': 16, 'country_name': 'Europe...
# 11  {'competition_id': 16, 'country_name': 'Europe...
# 12  {'competition_id': 16, 'country_name': 'Europe...
# 13  {'competition_id': 16, 'country_name': 'Europe...
#
#                                            season  \
# 0    {'season_id': 1, 'season_name': '2017/2018'}
# 1    {'season_id': 2, 'season_name': '2016/2017'}
# 2   {'season_id': 21, 'season_name': '2009/2010'}
# 3   {'season_id': 22, 'season_name': '2010/2011'}
# 4   {'season_id': 23, 'season_name': '2011/2012'}
# 5   {'season_id': 24, 'season_name': '2012/2013'}
# 6   {'season_id': 25, 'season_name': '2013/2014'}
# 7   {'season_id': 26, 'season_name': '2014/2015'}
# 8   {'season_id': 27, 'season_name': '2015/2016'}
# 9   {'season_id': 37, 'season_name': '2004/2005'}
# 10  {'season_id': 39, 'season_name': '2006/2007'}
# 11   {'season_id': 4, 'season_name': '2018/2019'}
# 12  {'season_id': 41, 'season_name': '2008/2009'}
# 13  {'season_id': 44, 'season_name': '2003/2004'}
#
#                                             home_team  \
# 0   {'home_team_id': 220, 'home_team_name': 'Real ...
# 1   {'home_team_id': 224, 'home_team_name': 'Juven...
# 2   {'home_team_id': 169, 'home_team_name': 'Bayer...
# 3   {'home_team_id': 217, 'home_team_name': 'Barce...
# 4   {'home_team_id': 169, 'home_team_name': 'Bayer...
# 5   {'home_team_id': 180, 'home_team_name': 'Borus...
# 6   {'home_team_id': 220, 'home_team_name': 'Real ...
# 7   {'home_team_id': 224, 'home_team_name': 'Juven...
# 8   {'home_team_id': 220, 'home_team_name': 'Real ...
# 9   {'home_team_id': 243, 'home_team_name': 'AC Mi...
# 10  {'home_team_id': 243, 'home_team_name': 'AC Mi...
# 11  {'home_team_id': 38, 'home_team_name': 'Totten...
# 12  {'home_team_id': 217, 'home_team_name': 'Barce...
# 13  {'home_team_id': 129, 'home_team_name': 'AS Mo...
#
#                                             away_team  home_score  away_score  \
# 0   {'away_team_id': 24, 'away_team_name': 'Liverp...           3           1
# 1   {'away_team_id': 220, 'away_team_name': 'Real ...           1           4
# 2   {'away_team_id': 238, 'away_team_name': 'Inter...           0           2
# 3   {'away_team_id': 39, 'away_team_name': 'Manche...           3           1
# 4   {'away_team_id': 33, 'away_team_name': 'Chelse...           1           1
# 5   {'away_team_id': 169, 'away_team_name': 'Bayer...           1           2
# 6   {'away_team_id': 212, 'away_team_name': 'Atlét...           4           1
# 7   {'away_team_id': 217, 'away_team_name': 'Barce...           1           3
# 8   {'away_team_id': 212, 'away_team_name': 'Atlét...           1           1
# 9   {'away_team_id': 24, 'away_team_name': 'Liverp...           3           3
# 10  {'away_team_id': 24, 'away_team_name': 'Liverp...           2           1
# 11  {'away_team_id': 24, 'away_team_name': 'Liverp...           0           2
# 12  {'away_team_id': 39, 'away_team_name': 'Manche...           2           0
# 13  {'away_team_id': 256, 'away_team_name': 'FC Po...           0           3
#
#    match_status                last_updated  \
# 0     available            2020-07-29T05:00
# 1     available            2020-07-29T05:00
# 2     available            2020-07-29T05:00
# 3     available            2020-07-29T05:00
# 4     available            2020-07-29T05:00
# 5     available            2020-07-29T05:00
# 6     available            2020-07-29T05:00
# 7     available            2020-07-29T05:00
# 8     available            2020-07-29T05:00
# 9     available            2020-07-29T05:00
# 10    available            2020-07-29T05:00
# 11    available            2020-07-29T05:00
# 12    available  2020-08-30T10:18:39.435424
# 13    available            2020-07-29T05:00
#
#                                              metadata  match_week  \
# 0   {'data_version': '1.1.0', 'shot_fidelity_versi...           7
# 1                           {'data_version': '1.0.3'}           7
# 2                           {'data_version': '1.0.3'}           1
# 3                           {'data_version': '1.0.3'}           1
# 4                           {'data_version': '1.0.3'}           7
# 5                           {'data_version': '1.0.3'}           7
# 6                           {'data_version': '1.0.3'}           7
# 7                           {'data_version': '1.0.3'}           7
# 8                           {'data_version': '1.0.3'}           7
# 9   {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 10  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 11  {'data_version': '1.1.0', 'shot_fidelity_versi...          13
# 12  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 13  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
#
#               competition_stage  \
# 0   {'id': 26, 'name': 'Final'}
# 1   {'id': 26, 'name': 'Final'}
# 2   {'id': 26, 'name': 'Final'}
# 3   {'id': 26, 'name': 'Final'}
# 4   {'id': 26, 'name': 'Final'}
# 5   {'id': 26, 'name': 'Final'}
# 6   {'id': 26, 'name': 'Final'}
# 7   {'id': 26, 'name': 'Final'}
# 8   {'id': 26, 'name': 'Final'}
# 9   {'id': 26, 'name': 'Final'}
# 10  {'id': 26, 'name': 'Final'}
# 11  {'id': 26, 'name': 'Final'}
# 12  {'id': 26, 'name': 'Final'}
# 13  {'id': 26, 'name': 'Final'}
#
#                                               stadium  \
# 0   {'id': 4222, 'name': 'NSK Olimpijs'kyj', 'coun...
# 1   {'id': 113891, 'name': 'Principality Stadium',...
# 2   {'id': 353, 'name': 'Estadio Santiago Bernabéu...
# 3   {'id': 4666, 'name': 'Wembley Stadium', 'count...
# 4   {'id': 4867, 'name': 'Allianz Arena', 'country...
# 5   {'id': 4666, 'name': 'Wembley Stadium', 'count...
# 6   {'id': 611, 'name': 'Estádio do Sport Lisboa e...
# 7   {'id': 367, 'name': 'Olympiastadion Berlin', '...
# 8   {'id': 388, 'name': 'Stadio Giuseppe Meazza', ...
# 9                                                 NaN
# 10  {'id': 1454, 'name': 'Olympiako Stadio Spyros ...
# 11                                                NaN
# 12  {'id': 381, 'name': 'Stadio Olimpico', 'countr...
# 13                                                NaN
#
#                                               referee
# 0                     {'id': 727, 'name': 'M. Mažić'}
# 1   {'id': 226, 'name': 'F. Brych', 'country': {'i...
# 2                      {'id': 708, 'name': 'H. Webb'}
# 3   {'id': 449, 'name': 'V. Kassai', 'country': {'...
# 4                {'id': 717, 'name': 'Pedro Proença'}
# 5   {'id': 419, 'name': 'N. Rizzoli', 'country': {...
# 6   {'id': 287, 'name': 'B. Kuipers', 'country': {...
# 7   {'id': 581, 'name': 'C. Çakιr', 'country': {'i...
# 8               {'id': 728, 'name': 'M. Clattenburg'}
# 9                        {'id': 1279, 'name': 'None'}
# 10                   {'id': 700, 'name': 'H. Fandel'}
# 11                                                NaN
# 12                  {'id': 705, 'name': 'M. Busacca'}
# 13                       {'id': 1279, 'name': 'None'}

# %% [markdown]
# The 'La Liga' dataframe consists of 485 matches, when comparing this with Lionel Messi's Wikipedia page we know this to be the amount of games that he has played for Barcelona in La Liga.
#
# The 'Champions League' dataframe consists of only 13 matches, these appear to the finals from each season, so probably won't be much use in our analysis.

# %% [markdown]
# -----------------------------------------------------
# A number of columns can be dropped from the 'La Liga' dataframe...

# %%
laliga_matches = laliga_matches.drop(columns=['competition', 'match_status', 'last_updated', 'metadata', 'competition_stage'])

# %%
laliga_matches.head()
# Out:
#    match_id  match_date      kick_off  \
# 0      9592  2017-09-09  20:45:00.000
# 1      9870  2018-04-07  20:45:00.000
# 2      9783  2018-02-04  16:15:00.000
# 3      9609  2017-09-19  22:00:00.000
# 4      9700  2017-12-02  13:00:00.000
#
#                                          season  \
# 0  {'season_id': 1, 'season_name': '2017/2018'}
# 1  {'season_id': 1, 'season_name': '2017/2018'}
# 2  {'season_id': 1, 'season_name': '2017/2018'}
# 3  {'season_id': 1, 'season_name': '2017/2018'}
# 4  {'season_id': 1, 'season_name': '2017/2018'}
#
#                                            home_team  \
# 0  {'home_team_id': 217, 'home_team_name': 'Barce...
# 1  {'home_team_id': 217, 'home_team_name': 'Barce...
# 2  {'home_team_id': 214, 'home_team_name': 'Espan...
# 3  {'home_team_id': 217, 'home_team_name': 'Barce...
# 4  {'home_team_id': 217, 'home_team_name': 'Barce...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 214, 'away_team_name': 'Espan...           5           0
# 1  {'away_team_id': 205, 'away_team_name': 'Legan...           3           1
# 2  {'away_team_id': 217, 'away_team_name': 'Barce...           1           1
# 3  {'away_team_id': 322, 'away_team_name': 'Eibar...           6           1
# 4  {'away_team_id': 209, 'away_team_name': 'Celta...           2           2
#
#    match_week                                            stadium  \
# 0           3  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 1          31  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 2          22  {'id': 351, 'name': 'RCDE Stadium', 'country':...
# 3           5  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 4          14  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
#
#                                              referee
# 0  {'id': 183, 'name': 'Jesús Gil', 'country': {'...
# 1  {'id': 215, 'name': 'Ricardo De Burgos', 'coun...
# 2  {'id': 183, 'name': 'Jesús Gil', 'country': {'...
# 3  {'id': 208, 'name': 'Alejandro Hernández', 'co...
# 4  {'id': 209, 'name': 'Mario Melero', 'country':...

# %% [markdown]
# ## Splitting columns containing dictionaries...

# %% [markdown]
# There are a number of columns that contain dictionaries and sub-dictionaries, so I need to split these into separate columns, delete unwanted columns and then join them onto the main dataframe...

# %%
season_df = pd.json_normalize(laliga_matches['season'])
season_df.head()
# Out:
#    season_id season_name
# 0          1   2017/2018
# 1          1   2017/2018
# 2          1   2017/2018
# 3          1   2017/2018
# 4          1   2017/2018

# %%
home_team_df = pd.json_normalize(laliga_matches['home_team'])
home_team_df = home_team_df.drop(columns=['home_team_gender', 'home_team_group', 'country.id', 'country.name'])
home_team_df.head()
# Out:
#    home_team_id home_team_name  \
# 0           217      Barcelona
# 1           217      Barcelona
# 2           214       Espanyol
# 3           217      Barcelona
# 4           217      Barcelona
#
#                                             managers
# 0  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...
# 1  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...
# 2  [{'id': 236, 'name': 'Enrique Sánchez Flores',...
# 3  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...
# 4  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...

# %%
home_manager_df = home_team_df['managers'].apply(pd.Series).add_prefix('home_manager_')
home_manager_df.head()
# Out:
#                                       home_manager_0
# 0  {'id': 227, 'name': 'Ernesto Valverde Tejedor'...
# 1  {'id': 227, 'name': 'Ernesto Valverde Tejedor'...
# 2  {'id': 236, 'name': 'Enrique Sánchez Flores', ...
# 3  {'id': 227, 'name': 'Ernesto Valverde Tejedor'...
# 4  {'id': 227, 'name': 'Ernesto Valverde Tejedor'...

# %%
home_manager_df = home_manager_df['home_manager_0'].apply(pd.Series).add_prefix('home_manager_')
home_manager_df.head()
# Out:
#    home_manager_0          home_manager_country home_manager_dob  \
# 0             NaN  {'id': 214, 'name': 'Spain'}             None
# 1             NaN  {'id': 214, 'name': 'Spain'}             None
# 2             NaN  {'id': 214, 'name': 'Spain'}             None
# 3             NaN  {'id': 214, 'name': 'Spain'}             None
# 4             NaN  {'id': 214, 'name': 'Spain'}             None
#
#    home_manager_id         home_manager_name  home_manager_nickname
# 0            227.0  Ernesto Valverde Tejedor       Ernesto Valverde
# 1            227.0  Ernesto Valverde Tejedor       Ernesto Valverde
# 2            236.0    Enrique Sánchez Flores  Quique Sánchez Flores
# 3            227.0  Ernesto Valverde Tejedor       Ernesto Valverde
# 4            227.0  Ernesto Valverde Tejedor       Ernesto Valverde

# %%
home_manager_country_df = home_manager_df['home_manager_country'].apply(pd.Series).add_prefix('home_manager_country_')
home_manager_country_df.head()
# Out:
#    home_manager_country_0  home_manager_country_id home_manager_country_name
# 0                     NaN                    214.0                     Spain
# 1                     NaN                    214.0                     Spain
# 2                     NaN                    214.0                     Spain
# 3                     NaN                    214.0                     Spain
# 4                     NaN                    214.0                     Spain

# %%
home_team_df = home_team_df.join([home_manager_df, home_manager_country_df])

# %%
home_team_df.head()
# Out:
#    home_team_id home_team_name  \
# 0           217      Barcelona
# 1           217      Barcelona
# 2           214       Espanyol
# 3           217      Barcelona
# 4           217      Barcelona
#
#                                             managers  home_manager_0  \
# 0  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...             NaN
# 1  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...             NaN
# 2  [{'id': 236, 'name': 'Enrique Sánchez Flores',...             NaN
# 3  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...             NaN
# 4  [{'id': 227, 'name': 'Ernesto Valverde Tejedor...             NaN
#
#            home_manager_country home_manager_dob  home_manager_id  \
# 0  {'id': 214, 'name': 'Spain'}             None            227.0
# 1  {'id': 214, 'name': 'Spain'}             None            227.0
# 2  {'id': 214, 'name': 'Spain'}             None            236.0
# 3  {'id': 214, 'name': 'Spain'}             None            227.0
# 4  {'id': 214, 'name': 'Spain'}             None            227.0
#
#           home_manager_name  home_manager_nickname  home_manager_country_0  \
# 0  Ernesto Valverde Tejedor       Ernesto Valverde                     NaN
# 1  Ernesto Valverde Tejedor       Ernesto Valverde                     NaN
# 2    Enrique Sánchez Flores  Quique Sánchez Flores                     NaN
# 3  Ernesto Valverde Tejedor       Ernesto Valverde                     NaN
# 4  Ernesto Valverde Tejedor       Ernesto Valverde                     NaN
#
#    home_manager_country_id home_manager_country_name
# 0                    214.0                     Spain
# 1                    214.0                     Spain
# 2                    214.0                     Spain
# 3                    214.0                     Spain
# 4                    214.0                     Spain

# %% [markdown]
# Drop unwanted columns created by splitting...

# %%
home_team_df = home_team_df.drop(columns=['managers', 'home_manager_0', 'home_manager_country', 
                                          'home_manager_dob', 'home_manager_name', 'home_manager_country_0'])

# %%
home_team_df.head()
# Out:
#    home_team_id home_team_name  home_manager_id  home_manager_nickname  \
# 0           217      Barcelona            227.0       Ernesto Valverde
# 1           217      Barcelona            227.0       Ernesto Valverde
# 2           214       Espanyol            236.0  Quique Sánchez Flores
# 3           217      Barcelona            227.0       Ernesto Valverde
# 4           217      Barcelona            227.0       Ernesto Valverde
#
#    home_manager_country_id home_manager_country_name
# 0                    214.0                     Spain
# 1                    214.0                     Spain
# 2                    214.0                     Spain
# 3                    214.0                     Spain
# 4                    214.0                     Spain

# %% [markdown]
# Repeat same whole process carried out on 'home_team_df' to 'away_team_df'...

# %%
away_team_df = pd.json_normalize(laliga_matches['away_team'])
away_team_df = away_team_df.drop(columns=['away_team_gender', 'away_team_group', 'country.id', 'country.name'])
away_manager_df = away_team_df['managers'].apply(pd.Series).add_prefix('away_manager_')
away_manager_df = away_manager_df['away_manager_0'].apply(pd.Series).add_prefix('away_manager_')
away_manager_country_df = away_manager_df['away_manager_country'].apply(pd.Series).add_prefix('away_manager_country_')
away_team_df = away_team_df.join([away_manager_df, away_manager_country_df])
away_team_df = away_team_df.drop(columns=['managers', 'away_manager_0', 'away_manager_country', 
                                          'away_manager_dob', 'away_manager_name', 'away_manager_country_0'])

# %%
away_team_df.head()
# Out:
#    away_team_id away_team_name  away_manager_id  away_manager_nickname  \
# 0           214       Espanyol            236.0  Quique Sánchez Flores
# 1           205        Leganés             84.0         Asier Garitano
# 2           217      Barcelona            227.0       Ernesto Valverde
# 3           322          Eibar            221.0   José Luis Mendilibar
# 4           209     Celta Vigo            208.0      Juan Carlos Unzué
#
#    away_manager_country_id away_manager_country_name
# 0                    214.0                     Spain
# 1                    214.0                     Spain
# 2                    214.0                     Spain
# 3                    214.0                     Spain
# 4                    214.0                     Spain

# %%
stadium_df = laliga_matches['stadium'].apply(pd.Series).add_prefix('stadium_')
stadium_df = stadium_df.drop(columns=['stadium_0', 'stadium_country'])
stadium_df.head()
# Out:
#    stadium_id  stadium_name
# 0       342.0      Camp Nou
# 1       342.0      Camp Nou
# 2       351.0  RCDE Stadium
# 3       342.0      Camp Nou
# 4       342.0      Camp Nou

# %%
referee_df = laliga_matches['referee'].apply(pd.Series).add_prefix('referee_')
referee_df.head()
# Out:
#    referee_0               referee_country  referee_id         referee_name
# 0        NaN  {'id': 214, 'name': 'Spain'}       183.0            Jesús Gil
# 1        NaN  {'id': 112, 'name': 'Italy'}       215.0    Ricardo De Burgos
# 2        NaN  {'id': 214, 'name': 'Spain'}       183.0            Jesús Gil
# 3        NaN  {'id': 112, 'name': 'Italy'}       208.0  Alejandro Hernández
# 4        NaN  {'id': 112, 'name': 'Italy'}       209.0         Mario Melero

# %%
referee_country_df = referee_df['referee_country'].apply(pd.Series).add_prefix('referee_country_')
referee_country_df.head()
# Out:
#    referee_country_0  referee_country_id referee_country_name
# 0                NaN               214.0                Spain
# 1                NaN               112.0                Italy
# 2                NaN               214.0                Spain
# 3                NaN               112.0                Italy
# 4                NaN               112.0                Italy

# %%
referee_df = referee_df.join(referee_country_df)
referee_df.head()
# Out:
#    referee_0               referee_country  referee_id         referee_name  \
# 0        NaN  {'id': 214, 'name': 'Spain'}       183.0            Jesús Gil
# 1        NaN  {'id': 112, 'name': 'Italy'}       215.0    Ricardo De Burgos
# 2        NaN  {'id': 214, 'name': 'Spain'}       183.0            Jesús Gil
# 3        NaN  {'id': 112, 'name': 'Italy'}       208.0  Alejandro Hernández
# 4        NaN  {'id': 112, 'name': 'Italy'}       209.0         Mario Melero
#
#    referee_country_0  referee_country_id referee_country_name
# 0                NaN               214.0                Spain
# 1                NaN               112.0                Italy
# 2                NaN               214.0                Spain
# 3                NaN               112.0                Italy
# 4                NaN               112.0                Italy

# %%
referee_df = referee_df.drop(columns=['referee_0', 'referee_country', 'referee_country_0'])
referee_df.head()
# Out:
#    referee_id         referee_name  referee_country_id referee_country_name
# 0       183.0            Jesús Gil               214.0                Spain
# 1       215.0    Ricardo De Burgos               112.0                Italy
# 2       183.0            Jesús Gil               214.0                Spain
# 3       208.0  Alejandro Hernández               112.0                Italy
# 4       209.0         Mario Melero               112.0                Italy

# %% [markdown]
# Join all dataframes onto 'la_liga_matches' dataframe...

# %%
laliga_matches = laliga_matches.join([season_df, home_team_df, away_team_df, stadium_df, referee_df])
laliga_matches.head()
# Out:
#    match_id  match_date      kick_off  \
# 0      9592  2017-09-09  20:45:00.000
# 1      9870  2018-04-07  20:45:00.000
# 2      9783  2018-02-04  16:15:00.000
# 3      9609  2017-09-19  22:00:00.000
# 4      9700  2017-12-02  13:00:00.000
#
#                                          season  \
# 0  {'season_id': 1, 'season_name': '2017/2018'}
# 1  {'season_id': 1, 'season_name': '2017/2018'}
# 2  {'season_id': 1, 'season_name': '2017/2018'}
# 3  {'season_id': 1, 'season_name': '2017/2018'}
# 4  {'season_id': 1, 'season_name': '2017/2018'}
#
#                                            home_team  \
# 0  {'home_team_id': 217, 'home_team_name': 'Barce...
# 1  {'home_team_id': 217, 'home_team_name': 'Barce...
# 2  {'home_team_id': 214, 'home_team_name': 'Espan...
# 3  {'home_team_id': 217, 'home_team_name': 'Barce...
# 4  {'home_team_id': 217, 'home_team_name': 'Barce...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 214, 'away_team_name': 'Espan...           5           0
# 1  {'away_team_id': 205, 'away_team_name': 'Legan...           3           1
# 2  {'away_team_id': 217, 'away_team_name': 'Barce...           1           1
# 3  {'away_team_id': 322, 'away_team_name': 'Eibar...           6           1
# 4  {'away_team_id': 209, 'away_team_name': 'Celta...           2           2
#
#    match_week                                            stadium  \
# 0           3  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 1          31  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 2          22  {'id': 351, 'name': 'RCDE Stadium', 'country':...
# 3           5  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 4          14  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
#
#                                              referee  season_id season_name  \
# 0  {'id': 183, 'name': 'Jesús Gil', 'country': {'...          1   2017/2018
# 1  {'id': 215, 'name': 'Ricardo De Burgos', 'coun...          1   2017/2018
# 2  {'id': 183, 'name': 'Jesús Gil', 'country': {'...          1   2017/2018
# 3  {'id': 208, 'name': 'Alejandro Hernández', 'co...          1   2017/2018
# 4  {'id': 209, 'name': 'Mario Melero', 'country':...          1   2017/2018
#
#    home_team_id home_team_name  home_manager_id  home_manager_nickname  \
# 0           217      Barcelona            227.0       Ernesto Valverde
# 1           217      Barcelona            227.0       Ernesto Valverde
# 2           214       Espanyol            236.0  Quique Sánchez Flores
# 3           217      Barcelona            227.0       Ernesto Valverde
# 4           217      Barcelona            227.0       Ernesto Valverde
#
#    home_manager_country_id home_manager_country_name  away_team_id  \
# 0                    214.0                     Spain           214
# 1                    214.0                     Spain           205
# 2                    214.0                     Spain           217
# 3                    214.0                     Spain           322
# 4                    214.0                     Spain           209
#
#   away_team_name  away_manager_id  away_manager_nickname  \
# 0       Espanyol            236.0  Quique Sánchez Flores
# 1        Leganés             84.0         Asier Garitano
# 2      Barcelona            227.0       Ernesto Valverde
# 3          Eibar            221.0   José Luis Mendilibar
# 4     Celta Vigo            208.0      Juan Carlos Unzué
#
#    away_manager_country_id away_manager_country_name  stadium_id  \
# 0                    214.0                     Spain       342.0
# 1                    214.0                     Spain       342.0
# 2                    214.0                     Spain       351.0
# 3                    214.0                     Spain       342.0
# 4                    214.0                     Spain       342.0
#
#    stadium_name  referee_id         referee_name  referee_country_id  \
# 0      Camp Nou       183.0            Jesús Gil               214.0
# 1      Camp Nou       215.0    Ricardo De Burgos               112.0
# 2  RCDE Stadium       183.0            Jesús Gil               214.0
# 3      Camp Nou       208.0  Alejandro Hernández               112.0
# 4      Camp Nou       209.0         Mario Melero               112.0
#
#   referee_country_name
# 0                Spain
# 1                Italy
# 2                Spain
# 3                Italy
# 4                Italy

# %% [markdown]
# Drop unwanted columns...

# %%
laliga_matches = laliga_matches.drop(columns=['season', 'home_team', 'away_team', 'stadium', 'referee'])
laliga_matches.head()
# Out:
#    match_id  match_date      kick_off  home_score  away_score  match_week  \
# 0      9592  2017-09-09  20:45:00.000           5           0           3
# 1      9870  2018-04-07  20:45:00.000           3           1          31
# 2      9783  2018-02-04  16:15:00.000           1           1          22
# 3      9609  2017-09-19  22:00:00.000           6           1           5
# 4      9700  2017-12-02  13:00:00.000           2           2          14
#
#    season_id season_name  home_team_id home_team_name  home_manager_id  \
# 0          1   2017/2018           217      Barcelona            227.0
# 1          1   2017/2018           217      Barcelona            227.0
# 2          1   2017/2018           214       Espanyol            236.0
# 3          1   2017/2018           217      Barcelona            227.0
# 4          1   2017/2018           217      Barcelona            227.0
#
#    home_manager_nickname  home_manager_country_id home_manager_country_name  \
# 0       Ernesto Valverde                    214.0                     Spain
# 1       Ernesto Valverde                    214.0                     Spain
# 2  Quique Sánchez Flores                    214.0                     Spain
# 3       Ernesto Valverde                    214.0                     Spain
# 4       Ernesto Valverde                    214.0                     Spain
#
#    away_team_id away_team_name  away_manager_id  away_manager_nickname  \
# 0           214       Espanyol            236.0  Quique Sánchez Flores
# 1           205        Leganés             84.0         Asier Garitano
# 2           217      Barcelona            227.0       Ernesto Valverde
# 3           322          Eibar            221.0   José Luis Mendilibar
# 4           209     Celta Vigo            208.0      Juan Carlos Unzué
#
#    away_manager_country_id away_manager_country_name  stadium_id  \
# 0                    214.0                     Spain       342.0
# 1                    214.0                     Spain       342.0
# 2                    214.0                     Spain       351.0
# 3                    214.0                     Spain       342.0
# 4                    214.0                     Spain       342.0
#
#    stadium_name  referee_id         referee_name  referee_country_id  \
# 0      Camp Nou       183.0            Jesús Gil               214.0
# 1      Camp Nou       215.0    Ricardo De Burgos               112.0
# 2  RCDE Stadium       183.0            Jesús Gil               214.0
# 3      Camp Nou       208.0  Alejandro Hernández               112.0
# 4      Camp Nou       209.0         Mario Melero               112.0
#
#   referee_country_name
# 0                Spain
# 1                Italy
# 2                Spain
# 3                Italy
# 4                Italy

# %% [markdown]
# ## Look into null/missing values...

# %%
laliga_matches.isnull().sum()
# Out:
# match_id                       0
# match_date                     0
# kick_off                       0
# home_score                     0
# away_score                     0
# match_week                     0
# season_id                      0
# season_name                    0
# home_team_id                   0
# home_team_name                 0
# home_manager_id              171
# home_manager_nickname        185
# home_manager_country_id      171
# home_manager_country_name    171
# away_team_id                   0
# away_team_name                 0
# away_manager_id              171
# away_manager_nickname        184
# away_manager_country_id      171
# away_manager_country_name    171
# stadium_id                     1
# stadium_name                   1
# referee_id                     1
# referee_name                   1
# referee_country_id           212
# referee_country_name         212
# dtype: int64

# %%
laliga_matches.loc[laliga_matches['stadium_id'].isna()]
# Out:
#      match_id  match_date      kick_off  home_score  away_score  match_week  \
# 367     16275  2019-04-23  21:30:00.000           0           2          34
#
#      season_id season_name  home_team_id    home_team_name  home_manager_id  \
# 367          4   2018/2019           206  Deportivo Alavés            187.0
#
#     home_manager_nickname  home_manager_country_id home_manager_country_name  \
# 367              Abelardo                    214.0                     Spain
#
#      away_team_id away_team_name  away_manager_id away_manager_nickname  \
# 367           217      Barcelona            227.0      Ernesto Valverde
#
#      away_manager_country_id away_manager_country_name  stadium_id  \
# 367                    214.0                     Spain         NaN
#
#     stadium_name  referee_id referee_name  referee_country_id  \
# 367          NaN         NaN          NaN                 NaN
#
#     referee_country_name
# 367                  NaN

# %% [markdown]
# I can see that the single null values we have for 'stadium_id', 'stadium_name', 'referee_id' & 'referee_name' all belong to this one record above.
#
# Having carried out some brief research I found out that the match was played at the 'Mendizorroza' stadium, and the referee was Adrián Cordero Vega from Spain.
#
# So I will search through to see if either this stadium or referee appear elsewhere in the dataframe, in order to get their ID codes...

# %%
laliga_matches.loc[laliga_matches['stadium_name'] == 'Mendizorroza']
# Out:
# Empty DataFrame
# Columns: [match_id, match_date, kick_off, home_score, away_score, match_week, season_id, season_name, home_team_id, home_team_name, home_manager_id, home_manager_nickname, home_manager_country_id, home_manager_country_name, away_team_id, away_team_name, away_manager_id, away_manager_nickname, away_manager_country_id, away_manager_country_name, stadium_id, stadium_name, referee_id, referee_name, referee_country_id, referee_country_name]
# Index: []

# %%
laliga_matches.loc[laliga_matches['home_team_name'] == 'Deportivo Alavés']
# Out:
#      match_id  match_date      kick_off  home_score  away_score  match_week  \
# 24       9581  2017-08-26  18:15:00.000           0           2           2
# 51     266273  2017-02-11  16:15:00.000           0           6          22
# 367     16275  2019-04-23  21:30:00.000           0           2          34
# 452    303421  2020-07-19  17:00:00.000           0           5          38
#
#      season_id season_name  home_team_id    home_team_name  home_manager_id  \
# 24           1   2017/2018           206  Deportivo Alavés            511.0
# 51           2   2016/2017           206  Deportivo Alavés            681.0
# 367          4   2018/2019           206  Deportivo Alavés            187.0
# 452         42   2019/2020           206  Deportivo Alavés              2.0
#
#     home_manager_nickname  home_manager_country_id home_manager_country_name  \
# 24          Luis Zubeldía                     11.0                 Argentina
# 51                   None                     11.0                 Argentina
# 367              Abelardo                    214.0                     Spain
# 452            Juan Muñiz                    214.0                     Spain
#
#      away_team_id away_team_name  away_manager_id away_manager_nickname  \
# 24            217      Barcelona            227.0      Ernesto Valverde
# 51            217      Barcelona            793.0          Luis Enrique
# 367           217      Barcelona            227.0      Ernesto Valverde
# 452           217      Barcelona            238.0         Quique Setién
#
#      away_manager_country_id away_manager_country_name  stadium_id  \
# 24                     214.0                     Spain       348.0
# 51                     214.0                     Spain       348.0
# 367                    214.0                     Spain         NaN
# 452                    214.0                     Spain       348.0
#
#                 stadium_name  referee_id      referee_name  \
# 24   Estadio de Mendizorroza       223.0  Carlos Del Cerro
# 51   Estadio de Mendizorroza      1008.0        Clos Gómez
# 367                      NaN         NaN               NaN
# 452  Estadio de Mendizorroza       207.0     Juan Martínez
#
#      referee_country_id referee_country_name
# 24                112.0                Italy
# 51                  NaN                  NaN
# 367                 NaN                  NaN
# 452               112.0                Italy

# %%
laliga_matches.loc[laliga_matches['referee_name'] == 'Adrián Cordero Vega']
# Out:
# Empty DataFrame
# Columns: [match_id, match_date, kick_off, home_score, away_score, match_week, season_id, season_name, home_team_id, home_team_name, home_manager_id, home_manager_nickname, home_manager_country_id, home_manager_country_name, away_team_id, away_team_name, away_manager_id, away_manager_nickname, away_manager_country_id, away_manager_country_name, stadium_id, stadium_name, referee_id, referee_name, referee_country_id, referee_country_name]
# Index: []

# %% [markdown]
# Based on the results from the research and searches above, we can replace the null values for 'stadium_id', 'stadium_name', & 'referee_name', but we will need to assign the referee a new 'referee_id'...

# %% [markdown]
# Check to see which 'referee_id' values are not in use:

# %%
laliga_matches["referee_id"].unique()
# Out:
# array([ 183.,  215.,  208.,  209.,  211.,  218.,  222.,  220.,  219.,
#         180.,  223.,  216.,  224.,  217.,  221.,  207.,  210., 1008.,
#        1012.,  407., 1013., 1003., 1010., 1070., 1001., 1014.,  668.,
#         997., 1000., 1007., 1069., 1009., 1016., 1015.,  453.,  882.,
#         993.,  994.,  995.,  996.,  998., 1002., 1005., 1006., 1011.,
#          nan,  451.,  865.,  492.,  874.])

# %%
laliga_matches.loc[laliga_matches['home_team_name'] == 'Deportivo Alavés']
# Out:
#      match_id  match_date      kick_off  home_score  away_score  match_week  \
# 24       9581  2017-08-26  18:15:00.000           0           2           2
# 51     266273  2017-02-11  16:15:00.000           0           6          22
# 367     16275  2019-04-23  21:30:00.000           0           2          34
# 452    303421  2020-07-19  17:00:00.000           0           5          38
#
#      season_id season_name  home_team_id    home_team_name  home_manager_id  \
# 24           1   2017/2018           206  Deportivo Alavés            511.0
# 51           2   2016/2017           206  Deportivo Alavés            681.0
# 367          4   2018/2019           206  Deportivo Alavés            187.0
# 452         42   2019/2020           206  Deportivo Alavés              2.0
#
#     home_manager_nickname  home_manager_country_id home_manager_country_name  \
# 24          Luis Zubeldía                     11.0                 Argentina
# 51                   None                     11.0                 Argentina
# 367              Abelardo                    214.0                     Spain
# 452            Juan Muñiz                    214.0                     Spain
#
#      away_team_id away_team_name  away_manager_id away_manager_nickname  \
# 24            217      Barcelona            227.0      Ernesto Valverde
# 51            217      Barcelona            793.0          Luis Enrique
# 367           217      Barcelona            227.0      Ernesto Valverde
# 452           217      Barcelona            238.0         Quique Setién
#
#      away_manager_country_id away_manager_country_name  stadium_id  \
# 24                     214.0                     Spain       348.0
# 51                     214.0                     Spain       348.0
# 367                    214.0                     Spain         NaN
# 452                    214.0                     Spain       348.0
#
#                 stadium_name  referee_id      referee_name  \
# 24   Estadio de Mendizorroza       223.0  Carlos Del Cerro
# 51   Estadio de Mendizorroza      1008.0        Clos Gómez
# 367                      NaN         NaN               NaN
# 452  Estadio de Mendizorroza       207.0     Juan Martínez
#
#      referee_country_id referee_country_name
# 24                112.0                Italy
# 51                  NaN                  NaN
# 367                 NaN                  NaN
# 452               112.0                Italy

# %%
laliga_matches.loc[367, 'stadium_id'] = 348
laliga_matches.loc[367, 'stadium_name'] = 'Estadio de Mendizorroza'
laliga_matches.loc[367, 'referee_name'] = 'Adrián Cordero Vega'
laliga_matches.loc[367, 'referee_country_id'] = 214
laliga_matches.loc[367, 'referee_country_name'] = 'Spain'
laliga_matches.loc[367, 'referee_id'] = 244

# %% [markdown]
# Check that the fields have been correctly updated:

# %%
laliga_matches.iloc[367]
# Out:
# match_id                                       16275
# match_date                                2019-04-23
# kick_off                                21:30:00.000
# home_score                                         0
# away_score                                         2
# match_week                                        34
# season_id                                          4
# season_name                                2018/2019
# home_team_id                                     206
# home_team_name                      Deportivo Alavés
# home_manager_id                                  187
# home_manager_nickname                       Abelardo
# home_manager_country_id                          214
# home_manager_country_name                      Spain
# away_team_id                                     217
# away_team_name                             Barcelona
# away_manager_id                                  227
# away_manager_nickname               Ernesto Valverde
# away_manager_country_id                          214
# away_manager_country_name                      Spain
# stadium_id                                       348
# stadium_name                 Estadio de Mendizorroza
# referee_id                                       244
# referee_name                     Adrián Cordero Vega
# referee_country_id                               214
# referee_country_name                           Spain
# Name: 367, dtype: object

# %%
laliga_matches.isnull().sum()
# Out:
# match_id                       0
# match_date                     0
# kick_off                       0
# home_score                     0
# away_score                     0
# match_week                     0
# season_id                      0
# season_name                    0
# home_team_id                   0
# home_team_name                 0
# home_manager_id              171
# home_manager_nickname        185
# home_manager_country_id      171
# home_manager_country_name    171
# away_team_id                   0
# away_team_name                 0
# away_manager_id              171
# away_manager_nickname        184
# away_manager_country_id      171
# away_manager_country_name    171
# stadium_id                     0
# stadium_name                   0
# referee_id                     0
# referee_name                   0
# referee_country_id           211
# referee_country_name         211
# dtype: int64

# %% [markdown]
# I'm still left with several columns that have quite a high number of null values, relating to the home/away manager and referee. I could probably find out the correct values, but it would be very time consuming.
#
# Therefore, for now I won't use these variables in my analysis, but could revisit them if I have time in the future. I will create a subset that contains only the columns with zero null values...

# %%
la_liga_matches = laliga_matches[laliga_matches.columns[~laliga_matches.isnull().any()]]

# %% [markdown]
# ## Check data types...

# %%
la_liga_matches.dtypes
# Out:
# match_id            int64
# match_date         object
# kick_off           object
# home_score          int64
# away_score          int64
# match_week          int64
# season_id           int64
# season_name        object
# home_team_id        int64
# home_team_name     object
# away_team_id        int64
# away_team_name     object
# stadium_id        float64
# stadium_name       object
# referee_id        float64
# referee_name       object
# dtype: object

# %% [markdown]
# 'match_date' should be datetime, the format of 'kick_off' needs to be changed, plus 'stadium_id' & 'referee_id' need to be converted to int...

# %%
la_liga_matches['match_date'] = pd.to_datetime(la_liga_matches['match_date'], format='%Y/%m/%d')
la_liga_matches['kick_off'] = la_liga_matches['kick_off'].str[0:5]
#laliga_matches[col] = laliga_matches[col].astype('int64')
la_liga_matches = la_liga_matches.astype({'stadium_id': 'int64', 'referee_id': 'int64'})
# Out:
# C:\Users\paul_\anaconda3\envs\matrix\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\paul_\anaconda3\envs\matrix\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
la_liga_matches.dtypes
# Out:
# match_id                   int64
# match_date        datetime64[ns]
# kick_off                  object
# home_score                 int64
# away_score                 int64
# match_week                 int64
# season_id                  int64
# season_name               object
# home_team_id               int64
# home_team_name            object
# away_team_id               int64
# away_team_name            object
# stadium_id                 int64
# stadium_name              object
# referee_id                 int64
# referee_name              object
# dtype: object

# %%
la_liga_matches.head()
# Out:
#    match_id match_date kick_off  home_score  away_score  match_week  \
# 0      9592 2017-09-09    20:45           5           0           3
# 1      9870 2018-04-07    20:45           3           1          31
# 2      9783 2018-02-04    16:15           1           1          22
# 3      9609 2017-09-19    22:00           6           1           5
# 4      9700 2017-12-02    13:00           2           2          14
#
#    season_id season_name  home_team_id home_team_name  away_team_id  \
# 0          1   2017/2018           217      Barcelona           214
# 1          1   2017/2018           217      Barcelona           205
# 2          1   2017/2018           214       Espanyol           217
# 3          1   2017/2018           217      Barcelona           322
# 4          1   2017/2018           217      Barcelona           209
#
#   away_team_name  stadium_id  stadium_name  referee_id         referee_name
# 0       Espanyol         342      Camp Nou         183            Jesús Gil
# 1        Leganés         342      Camp Nou         215    Ricardo De Burgos
# 2      Barcelona         351  RCDE Stadium         183            Jesús Gil
# 3          Eibar         342      Camp Nou         208  Alejandro Hernández
# 4     Celta Vigo         342      Camp Nou         209         Mario Melero

# %% [markdown]
# ## Reorder columns...

# %%
la_liga_matches.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'home_score', 'away_score',
#        'match_week', 'season_id', 'season_name', 'home_team_id',
#        'home_team_name', 'away_team_id', 'away_team_name', 'stadium_id',
#        'stadium_name', 'referee_id', 'referee_name'],
#       dtype='object')

# %%
la_liga_matches = la_liga_matches[['match_id', 'season_id', 'season_name', 'match_week', 'match_date', 'kick_off', 'home_score', 'away_score', 'home_team_id', 'home_team_name', 'away_team_id', 'away_team_name', 'stadium_id', 'stadium_name', 'referee_id', 'referee_name']]
la_liga_matches.head()
# Out:
#    match_id  season_id season_name  match_week match_date kick_off  \
# 0      9592          1   2017/2018           3 2017-09-09    20:45
# 1      9870          1   2017/2018          31 2018-04-07    20:45
# 2      9783          1   2017/2018          22 2018-02-04    16:15
# 3      9609          1   2017/2018           5 2017-09-19    22:00
# 4      9700          1   2017/2018          14 2017-12-02    13:00
#
#    home_score  away_score  home_team_id home_team_name  away_team_id  \
# 0           5           0           217      Barcelona           214
# 1           3           1           217      Barcelona           205
# 2           1           1           214       Espanyol           217
# 3           6           1           217      Barcelona           322
# 4           2           2           217      Barcelona           209
#
#   away_team_name  stadium_id  stadium_name  referee_id         referee_name
# 0       Espanyol         342      Camp Nou         183            Jesús Gil
# 1        Leganés         342      Camp Nou         215    Ricardo De Burgos
# 2      Barcelona         351  RCDE Stadium         183            Jesús Gil
# 3          Eibar         342      Camp Nou         208  Alejandro Hernández
# 4     Celta Vigo         342      Camp Nou         209         Mario Melero

# %% [markdown]
# I will need the unique values from the 'match_id' column when importing the 'events' data, so will create that list now...

# %%
match_codes = list(laliga_matches['match_id'].unique())

# %%
len(match_codes)
# Out:
# 485

# %% [markdown]
# # 3) 'events' data

# %% [markdown]
# I'm expecting the following processes to take some time to run, so I'll import a module to show progress.

# %%
import tqdm

# %% [markdown]
# Import and combine multiple JSON files into a single dataframe using the 'match_codes' list created earlier.

# %%
events_base_dir = r'..\data\original-data\events'
events_list = []

for code in tqdm.tqdm(match_codes):
    file_dir = events_base_dir + '\\' + str(code) + '.json'
    #for file in os.listdir(events_base_dir):
        #json_path = os.path.join(events_base_dir, file)
    json_data = pd.read_json(file_dir, orient='records')
    json_data['match_id'] = code
    events_list.append(json_data)
events = pd.concat(events_list, axis=0, ignore_index=True)
# Out:
# 100%|██████████| 485/485 [05:22<00:00,  1.51it/s]

# %%
events.head()
# Out:
#                                      id  index  period  \
# 0  62fcd4a2-94ed-42f0-9c4e-d994ae217440      1       1
# 1  dcd47e2f-6a76-499e-abee-413417bd067e      2       1
# 2  1d6e44c2-fb77-479e-bb98-851952e9b3f9      3       1
# 3  d8eaa47d-d089-45a6-b3b4-a59ab8f65a6a      4       1
# 4  547584c5-1b05-46ce-b61a-cd124d20b385      5       1
#
#                 timestamp  minute  second                               type  \
# 0 2020-09-30 00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 1 2020-09-30 00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 2 2020-09-30 00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 3 2020-09-30 00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 4 2020-09-30 00:00:07.279       0       7         {'id': 30, 'name': 'Pass'}
#
#    possession                   possession_team  \
# 0           1  {'id': 217, 'name': 'Barcelona'}
# 1           1  {'id': 217, 'name': 'Barcelona'}
# 2           1  {'id': 217, 'name': 'Barcelona'}
# 3           1  {'id': 217, 'name': 'Barcelona'}
# 4           2  {'id': 217, 'name': 'Barcelona'}
#
#                          play_pattern                              team  \
# 0   {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
# 1   {'id': 1, 'name': 'Regular Play'}   {'id': 214, 'name': 'Espanyol'}
# 2   {'id': 1, 'name': 'Regular Play'}   {'id': 214, 'name': 'Espanyol'}
# 3   {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
# 4  {'id': 9, 'name': 'From Kick Off'}  {'id': 217, 'name': 'Barcelona'}
#
#    duration                                            tactics  \
# 0     0.000  {'formation': 442, 'lineup': [{'player': {'id'...
# 1     0.000  {'formation': 442, 'lineup': [{'player': {'id'...
# 2     0.000                                                NaN
# 3     0.000                                                NaN
# 4     0.806                                                NaN
#
#                            related_events  \
# 0                                     NaN
# 1                                     NaN
# 2  [d8eaa47d-d089-45a6-b3b4-a59ab8f65a6a]
# 3  [1d6e44c2-fb77-479e-bb98-851952e9b3f9]
# 4  [40265cdf-29b5-4e8a-8e9d-1d53a750ff51]
#
#                                              player  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4  {'id': 5246, 'name': 'Luis Alberto Suárez Díaz'}
#
#                                     position      location  \
# 0                                        NaN           NaN
# 1                                        NaN           NaN
# 2                                        NaN           NaN
# 3                                        NaN           NaN
# 4  {'id': 24, 'name': 'Left Center Forward'}  [61.0, 41.0]
#
#                                                 pass carry  under_pressure  \
# 0                                                NaN   NaN             NaN
# 1                                                NaN   NaN             NaN
# 2                                                NaN   NaN             NaN
# 3                                                NaN   NaN             NaN
# 4  {'recipient': {'id': 5203, 'name': 'Sergio Bus...   NaN             NaN
#
#   dribble ball_receipt  out clearance duel miscontrol shot goalkeeper  \
# 0     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 1     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 2     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 3     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 4     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
#
#    counterpress ball_recovery foul_won  off_camera foul_committed block  \
# 0           NaN           NaN      NaN         NaN            NaN   NaN
# 1           NaN           NaN      NaN         NaN            NaN   NaN
# 2           NaN           NaN      NaN         NaN            NaN   NaN
# 3           NaN           NaN      NaN         NaN            NaN   NaN
# 4           NaN           NaN      NaN         NaN            NaN   NaN
#
#   interception substitution bad_behaviour  match_id 50_50 injury_stoppage  \
# 0          NaN          NaN           NaN      9592   NaN             NaN
# 1          NaN          NaN           NaN      9592   NaN             NaN
# 2          NaN          NaN           NaN      9592   NaN             NaN
# 3          NaN          NaN           NaN      9592   NaN             NaN
# 4          NaN          NaN           NaN      9592   NaN             NaN
#
#   half_start player_off half_end
# 0        NaN        NaN      NaN
# 1        NaN        NaN      NaN
# 2        NaN        NaN      NaN
# 3        NaN        NaN      NaN
# 4        NaN        NaN      NaN

# %% [markdown]
# I'd like to subset the 'events' dataframe into separate seasons, but the dataframe only contains the 'match_id'. Therefore I will need to use this column to create a new 'season_name' column. I'll do this by subsetting the 'la_liga_matches' dataframe, and then merging with the 'events' dataframe.

# %%
match_season = la_liga_matches[['match_id', 'season_name']]
match_season
# Out:
#      match_id season_name
# 0        9592   2017/2018
# 1        9870   2017/2018
# 2        9783   2017/2018
# 3        9609   2017/2018
# 4        9700   2017/2018
# ..        ...         ...
# 480    303524   2019/2020
# 481    303451   2019/2020
# 482    303517   2019/2020
# 483    303682   2019/2020
# 484    303731   2019/2020
#
# [485 rows x 2 columns]

# %%
events = events.merge(match_season, how='left', on='match_id')

# %%
events.head()
# Out:
#                                      id  index  period  \
# 0  62fcd4a2-94ed-42f0-9c4e-d994ae217440      1       1
# 1  dcd47e2f-6a76-499e-abee-413417bd067e      2       1
# 2  1d6e44c2-fb77-479e-bb98-851952e9b3f9      3       1
# 3  d8eaa47d-d089-45a6-b3b4-a59ab8f65a6a      4       1
# 4  547584c5-1b05-46ce-b61a-cd124d20b385      5       1
#
#                 timestamp  minute  second                               type  \
# 0 2020-09-30 00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 1 2020-09-30 00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 2 2020-09-30 00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 3 2020-09-30 00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 4 2020-09-30 00:00:07.279       0       7         {'id': 30, 'name': 'Pass'}
#
#    possession                   possession_team  \
# 0           1  {'id': 217, 'name': 'Barcelona'}
# 1           1  {'id': 217, 'name': 'Barcelona'}
# 2           1  {'id': 217, 'name': 'Barcelona'}
# 3           1  {'id': 217, 'name': 'Barcelona'}
# 4           2  {'id': 217, 'name': 'Barcelona'}
#
#                          play_pattern                              team  \
# 0   {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
# 1   {'id': 1, 'name': 'Regular Play'}   {'id': 214, 'name': 'Espanyol'}
# 2   {'id': 1, 'name': 'Regular Play'}   {'id': 214, 'name': 'Espanyol'}
# 3   {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
# 4  {'id': 9, 'name': 'From Kick Off'}  {'id': 217, 'name': 'Barcelona'}
#
#    duration                                            tactics  \
# 0     0.000  {'formation': 442, 'lineup': [{'player': {'id'...
# 1     0.000  {'formation': 442, 'lineup': [{'player': {'id'...
# 2     0.000                                                NaN
# 3     0.000                                                NaN
# 4     0.806                                                NaN
#
#                            related_events  \
# 0                                     NaN
# 1                                     NaN
# 2  [d8eaa47d-d089-45a6-b3b4-a59ab8f65a6a]
# 3  [1d6e44c2-fb77-479e-bb98-851952e9b3f9]
# 4  [40265cdf-29b5-4e8a-8e9d-1d53a750ff51]
#
#                                              player  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4  {'id': 5246, 'name': 'Luis Alberto Suárez Díaz'}
#
#                                     position      location  \
# 0                                        NaN           NaN
# 1                                        NaN           NaN
# 2                                        NaN           NaN
# 3                                        NaN           NaN
# 4  {'id': 24, 'name': 'Left Center Forward'}  [61.0, 41.0]
#
#                                                 pass carry  under_pressure  \
# 0                                                NaN   NaN             NaN
# 1                                                NaN   NaN             NaN
# 2                                                NaN   NaN             NaN
# 3                                                NaN   NaN             NaN
# 4  {'recipient': {'id': 5203, 'name': 'Sergio Bus...   NaN             NaN
#
#   dribble ball_receipt  out clearance duel miscontrol shot goalkeeper  \
# 0     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 1     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 2     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 3     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
# 4     NaN          NaN  NaN       NaN  NaN        NaN  NaN        NaN
#
#    counterpress ball_recovery foul_won  off_camera foul_committed block  \
# 0           NaN           NaN      NaN         NaN            NaN   NaN
# 1           NaN           NaN      NaN         NaN            NaN   NaN
# 2           NaN           NaN      NaN         NaN            NaN   NaN
# 3           NaN           NaN      NaN         NaN            NaN   NaN
# 4           NaN           NaN      NaN         NaN            NaN   NaN
#
#   interception substitution bad_behaviour  match_id 50_50 injury_stoppage  \
# 0          NaN          NaN           NaN      9592   NaN             NaN
# 1          NaN          NaN           NaN      9592   NaN             NaN
# 2          NaN          NaN           NaN      9592   NaN             NaN
# 3          NaN          NaN           NaN      9592   NaN             NaN
# 4          NaN          NaN           NaN      9592   NaN             NaN
#
#   half_start player_off half_end season_name
# 0        NaN        NaN      NaN   2017/2018
# 1        NaN        NaN      NaN   2017/2018
# 2        NaN        NaN      NaN   2017/2018
# 3        NaN        NaN      NaN   2017/2018
# 4        NaN        NaN      NaN   2017/2018

# %% [markdown]
# # 4) 'lineups' data

# %% [markdown]
# To create the 'lineups' dataframe we will use the same process as with the 'events' dataframe...

# %%
lineups_base_dir = r'..\data\original-data\lineups'
lineups_list = []

for code in tqdm.tqdm(match_codes):
    file_dir = lineups_base_dir + '\\' + str(code) + '.json'
    #for file in os.listdir(events_base_dir):
        #json_path = os.path.join(events_base_dir, file)
    json_data = pd.read_json(file_dir, orient='records')
    json_data['match_id'] = code
    lineups_list.append(json_data)
lineups = pd.concat(lineups_list, axis=0, ignore_index=True)
# Out:
# 100%|██████████| 485/485 [00:07<00:00, 63.97it/s]

# %%
lineups.head()
# Out:
#    team_id  team_name                                             lineup  \
# 0      214   Espanyol  [{'player_id': 3236, 'player_name': 'Sergi Dar...
# 1      217  Barcelona  [{'player_id': 3726, 'player_name': 'Gerard De...
# 2      205    Leganés  [{'player_id': 3302, 'player_name': 'Nordin Am...
# 3      217  Barcelona  [{'player_id': 3501, 'player_name': 'Philippe ...
# 4      214   Espanyol  [{'player_id': 3236, 'player_name': 'Sergi Dar...
#
#    match_id
# 0      9592
# 1      9592
# 2      9870
# 3      9870
# 4      9783

# %%
match_season = la_liga_matches[['match_id', 'season_name']]
match_season
# Out:
#      match_id season_name
# 0        9592   2017/2018
# 1        9870   2017/2018
# 2        9783   2017/2018
# 3        9609   2017/2018
# 4        9700   2017/2018
# ..        ...         ...
# 480    303524   2019/2020
# 481    303451   2019/2020
# 482    303517   2019/2020
# 483    303682   2019/2020
# 484    303731   2019/2020
#
# [485 rows x 2 columns]

# %%
lineups = lineups.merge(match_season, how='left', on='match_id')

# %%
lineups.head()
# Out:
#    team_id  team_name                                             lineup  \
# 0      214   Espanyol  [{'player_id': 3236, 'player_name': 'Sergi Dar...
# 1      217  Barcelona  [{'player_id': 3726, 'player_name': 'Gerard De...
# 2      205    Leganés  [{'player_id': 3302, 'player_name': 'Nordin Am...
# 3      217  Barcelona  [{'player_id': 3501, 'player_name': 'Philippe ...
# 4      214   Espanyol  [{'player_id': 3236, 'player_name': 'Sergi Dar...
#
#    match_id season_name
# 0      9592   2017/2018
# 1      9592   2017/2018
# 2      9870   2017/2018
# 3      9870   2017/2018
# 4      9783   2017/2018

# %% [markdown]
# Split the 'lineups' dataframe into separate dataframes for Barcelona line-ups and opposition line-ups.

# %%
lineups_barcelona = lineups[lineups['team_name'] == 'Barcelona']
lineups_opposition = lineups[lineups['team_name'] != 'Barcelona']
lineups_barcelona.head()
# Out:
#    team_id  team_name                                             lineup  \
# 1      217  Barcelona  [{'player_id': 3726, 'player_name': 'Gerard De...
# 3      217  Barcelona  [{'player_id': 3501, 'player_name': 'Philippe ...
# 5      217  Barcelona  [{'player_id': 3501, 'player_name': 'Philippe ...
# 6      217  Barcelona  [{'player_id': 3726, 'player_name': 'Gerard De...
# 8      217  Barcelona  [{'player_id': 5203, 'player_name': 'Sergio Bu...
#
#    match_id season_name
# 1      9592   2017/2018
# 3      9870   2017/2018
# 5      9783   2017/2018
# 6      9609   2017/2018
# 8      9700   2017/2018

# %% [markdown]
# Similarly to the 'matches' data, the 'lineup' column contains dictionaries, so I need to split this column into separate columns, delete unwanted columns and then join them onto the main dataframe...

# %%
split_player_barcelona = lineups_barcelona['lineup'].apply(pd.Series).add_prefix('player_')
split_player_barcelona
# Out:
#                                               player_0  \
# 1    {'player_id': 3726, 'player_name': 'Gerard Deu...
# 3    {'player_id': 3501, 'player_name': 'Philippe C...
# 5    {'player_id': 3501, 'player_name': 'Philippe C...
# 6    {'player_id': 3726, 'player_name': 'Gerard Deu...
# 8    {'player_id': 5203, 'player_name': 'Sergio Bus...
# ..                                                 ...
# 961  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 962  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 965  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 966  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 968  {'player_id': 4447, 'player_name': 'Martin Bra...
#
#                                               player_1  \
# 1    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 3    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 5    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 6    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 8    {'player_id': 5211, 'player_name': 'Jordi Alba...
# ..                                                 ...
# 961  {'player_id': 5246, 'player_name': 'Luis Alber...
# 962  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 965  {'player_id': 5211, 'player_name': 'Jordi Alba...
# 966  {'player_id': 5211, 'player_name': 'Jordi Alba...
# 968  {'player_id': 5203, 'player_name': 'Sergio Bus...
#
#                                               player_2  \
# 1    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 3    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 5    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 6    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 8    {'player_id': 5213, 'player_name': 'Gerard Piq...
# ..                                                 ...
# 961  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 962  {'player_id': 5246, 'player_name': 'Luis Alber...
# 965  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 966  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 968  {'player_id': 5213, 'player_name': 'Gerard Piq...
#
#                                               player_3  \
# 1    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 3    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 5    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 6    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 8    {'player_id': 5216, 'player_name': 'Andrés Ini...
# ..                                                 ...
# 961  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 962  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 965  {'player_id': 5246, 'player_name': 'Luis Alber...
# 966  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 968  {'player_id': 5470, 'player_name': 'Ivan Rakit...
#
#                                               player_4  \
# 1    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 3    {'player_id': 5246, 'player_name': 'Luis Alber...
# 5    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 6    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 8    {'player_id': 5246, 'player_name': 'Luis Alber...
# ..                                                 ...
# 961  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 962  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 965  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 966  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 968  {'player_id': 5487, 'player_name': 'Antoine Gr...
#
#                                               player_5  \
# 1    {'player_id': 5246, 'player_name': 'Luis Alber...
# 3    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 5    {'player_id': 5246, 'player_name': 'Luis Alber...
# 6    {'player_id': 5246, 'player_name': 'Luis Alber...
# 8    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# ..                                                 ...
# 961  {'player_id': 5503, 'player_name': 'Lionel And...
# 962  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 965  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 966  {'player_id': 5503, 'player_name': 'Lionel And...
# 968  {'player_id': 5492, 'player_name': 'Samuel Yve...
#
#                                               player_6  \
# 1    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 3    {'player_id': 5477, 'player_name': 'Ousmane De...
# 5    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 6    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 8    {'player_id': 5492, 'player_name': 'Samuel Yve...
# ..                                                 ...
# 961  {'player_id': 5674, 'player_name': 'Moussa Wag...
# 962  {'player_id': 5503, 'player_name': 'Lionel And...
# 965  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 966  {'player_id': 6374, 'player_name': 'Nélson Cab...
# 968  {'player_id': 5503, 'player_name': 'Lionel And...
#
#                                               player_7  \
# 1    {'player_id': 5477, 'player_name': 'Ousmane De...
# 3    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 5    {'player_id': 5503, 'player_name': 'Lionel And...
# 6    {'player_id': 5503, 'player_name': 'Lionel And...
# 8    {'player_id': 5503, 'player_name': 'Lionel And...
# ..                                                 ...
# 961  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 962  {'player_id': 5674, 'player_name': 'Moussa Wag...
# 965  {'player_id': 5503, 'player_name': 'Lionel And...
# 966  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 968  {'player_id': 6374, 'player_name': 'Nélson Cab...
#
#                                               player_8  \
# 1    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 3    {'player_id': 5503, 'player_name': 'Lionel And...
# 5    {'player_id': 5542, 'player_name': 'José Paulo...
# 6    {'player_id': 5506, 'player_name': 'Javier Ale...
# 8    {'player_id': 5542, 'player_name': 'José Paulo...
# ..                                                 ...
# 961  {'player_id': 6590, 'player_name': 'Norberto M...
# 962  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 965  {'player_id': 6374, 'player_name': 'Nélson Cab...
# 966  {'player_id': 6826, 'player_name': 'Clément Le...
# 968  {'player_id': 6379, 'player_name': 'Sergi Robe...
#
#                                               player_9  \
# 1    {'player_id': 5503, 'player_name': 'Lionel And...
# 3    {'player_id': 5542, 'player_name': 'José Paulo...
# 5    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 6    {'player_id': 5542, 'player_name': 'José Paulo...
# 8    {'player_id': 6332, 'player_name': 'Thomas Ver...
# ..                                                 ...
# 961  {'player_id': 6826, 'player_name': 'Clément Le...
# 962  {'player_id': 6590, 'player_name': 'Norberto M...
# 965  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 966  {'player_id': 8118, 'player_name': 'Frenkie de...
# 968  {'player_id': 6590, 'player_name': 'Norberto M...
#
#                                              player_10  \
# 1    {'player_id': 5506, 'player_name': 'Javier Ale...
# 3    {'player_id': 6332, 'player_name': 'Thomas Ver...
# 5    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 6    {'player_id': 6332, 'player_name': 'Thomas Ver...
# 8    {'player_id': 6379, 'player_name': 'Sergi Robe...
# ..                                                 ...
# 961  {'player_id': 8118, 'player_name': 'Frenkie de...
# 962  {'player_id': 6826, 'player_name': 'Clément Le...
# 965  {'player_id': 6590, 'player_name': 'Norberto M...
# 966  {'player_id': 11392, 'player_name': 'Arthur He...
# 968  {'player_id': 6826, 'player_name': 'Clément Le...
#
#                                              player_11  \
# 1    {'player_id': 5542, 'player_name': 'José Paulo...
# 3    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 5    {'player_id': 6402, 'player_name': 'Francisco ...
# 6    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 8    {'player_id': 6400, 'player_name': 'Aleix Vida...
# ..                                                 ...
# 961  {'player_id': 8206, 'player_name': 'Arturo Era...
# 962  {'player_id': 8118, 'player_name': 'Frenkie de...
# 965  {'player_id': 6826, 'player_name': 'Clément Le...
# 966  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 968  {'player_id': 8118, 'player_name': 'Frenkie de...
#
#                                              player_12  \
# 1    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 3    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 5    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 6    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 8    {'player_id': 6402, 'player_name': 'Francisco ...
# ..                                                 ...
# 961  {'player_id': 11392, 'player_name': 'Arthur He...
# 962  {'player_id': 8206, 'player_name': 'Arturo Era...
# 965  {'player_id': 8118, 'player_name': 'Frenkie de...
# 966  {'player_id': 24841, 'player_name': 'Ricard Pu...
# 968  {'player_id': 8206, 'player_name': 'Arturo Era...
#
#                                              player_13  \
# 1    {'player_id': 6402, 'player_name': 'Francisco ...
# 3    {'player_id': 6402, 'player_name': 'Francisco ...
# 5    {'player_id': 20055, 'player_name': 'Marc-Andr...
# 6    {'player_id': 6400, 'player_name': 'Aleix Vida...
# 8    {'player_id': 6609, 'player_name': 'Denis Suár...
# ..                                                 ...
# 961  {'player_id': 13599, 'player_name': 'Carles Al...
# 962  {'player_id': 11532, 'player_name': 'Jean-Clai...
# 965  {'player_id': 8206, 'player_name': 'Arturo Era...
# 966  {'player_id': 30756, 'player_name': 'Anssumane...
# 968  {'player_id': 11392, 'player_name': 'Arthur He...
#
#                                              player_14  \
# 1    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 3    {'player_id': 6609, 'player_name': 'Denis Suár...
# 5                                                  NaN
# 6    {'player_id': 6609, 'player_name': 'Denis Suár...
# 8    {'player_id': 6849, 'player_name': 'Lucas Dign...
# ..                                                 ...
# 961  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 962  {'player_id': 13599, 'player_name': 'Carles Al...
# 965  {'player_id': 13599, 'player_name': 'Carles Al...
# 966                                                NaN
# 968  {'player_id': 17304, 'player_name': 'Héctor Ju...
#
#                                              player_15  \
# 1    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 3    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 5                                                  NaN
# 6    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 8    {'player_id': 8652, 'player_name': 'Jasper Cil...
# ..                                                 ...
# 961  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 962  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 965  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 966                                                NaN
# 968  {'player_id': 20055, 'player_name': 'Marc-Andr...
#
#                                              player_16  \
# 1    {'player_id': 10802, 'player_name': 'André Fil...
# 3    {'player_id': 10802, 'player_name': 'André Fil...
# 5                                                  NaN
# 6    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 8    {'player_id': 10802, 'player_name': 'André Fil...
# ..                                                 ...
# 961  {'player_id': 25006, 'player_name': 'Carles Pé...
# 962  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 965  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 966                                                NaN
# 968  {'player_id': 20734, 'player_name': 'Sergio Ak...
#
#                                              player_17 player_18 player_19  \
# 1    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 3    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 5                                                  NaN       NaN       NaN
# 6    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 8    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# ..                                                 ...       ...       ...
# 961  {'player_id': 30756, 'player_name': 'Anssumane...       NaN       NaN
# 962  {'player_id': 25006, 'player_name': 'Carles Pé...       NaN       NaN
# 965  {'player_id': 25006, 'player_name': 'Carles Pé...       NaN       NaN
# 966                                                NaN       NaN       NaN
# 968  {'player_id': 30756, 'player_name': 'Anssumane...       NaN       NaN
#
#     player_20 player_21 player_22
# 1         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 5         NaN       NaN       NaN
# 6         NaN       NaN       NaN
# 8         NaN       NaN       NaN
# ..        ...       ...       ...
# 961       NaN       NaN       NaN
# 962       NaN       NaN       NaN
# 965       NaN       NaN       NaN
# 966       NaN       NaN       NaN
# 968       NaN       NaN       NaN
#
# [485 rows x 23 columns]

# %%
split_player_opposition = lineups_opposition['lineup'].apply(pd.Series).add_prefix('player_')
split_player_opposition
# Out:
#                                               player_0  \
# 0    {'player_id': 3236, 'player_name': 'Sergi Dard...
# 2    {'player_id': 3302, 'player_name': 'Nordin Amr...
# 4    {'player_id': 3236, 'player_name': 'Sergi Dard...
# 7    {'player_id': 5687, 'player_name': 'Takashi In...
# 9    {'player_id': 5217, 'player_name': 'Iago Aspas...
# ..                                                 ...
# 960  {'player_id': 3245, 'player_name': 'Thomas Lem...
# 963  {'player_id': 7361, 'player_name': 'Pablo Chav...
# 964  {'player_id': 3265, 'player_name': 'José Luis ...
# 967  {'player_id': 6592, 'player_name': 'Rúben Migu...
# 969  {'player_id': 5687, 'player_name': 'Takashi In...
#
#                                               player_1  \
# 0    {'player_id': 6751, 'player_name': 'Javier Fue...
# 2    {'player_id': 6597, 'player_name': 'Gabriel Ap...
# 4    {'player_id': 5685, 'player_name': 'Carlos Alb...
# 7    {'player_id': 6698, 'player_name': 'Marko Dmit...
# 9    {'player_id': 5516, 'player_name': 'Pione Sist...
# ..                                                 ...
# 960  {'player_id': 3308, 'player_name': 'Kieran Tri...
# 963  {'player_id': 8654, 'player_name': 'Ante Budim...
# 964  {'player_id': 3513, 'player_name': 'Oliver Bur...
# 967  {'player_id': 6668, 'player_name': 'José Luis ...
# 969  {'player_id': 6698, 'player_name': 'Marko Dmit...
#
#                                               player_2  \
# 0    {'player_id': 6754, 'player_name': 'David Lópe...
# 2    {'player_id': 6598, 'player_name': 'Unai Busti...
# 4    {'player_id': 6754, 'player_name': 'David Lópe...
# 7    {'player_id': 6699, 'player_name': 'Ander Capa...
# 9    {'player_id': 6038, 'player_name': 'John Guide...
# ..                                                 ...
# 960  {'player_id': 3477, 'player_name': 'Álvaro Bor...
# 963  {'player_id': 8689, 'player_name': 'Aleksandar...
# 964  {'player_id': 6400, 'player_name': 'Aleix Vida...
# 967  {'player_id': 6680, 'player_name': 'Rubén Roch...
# 969  {'player_id': 6700, 'player_name': 'Sergio Enr...
#
#                                               player_3  \
# 0    {'player_id': 6756, 'player_name': 'Marc Navar...
# 2    {'player_id': 6599, 'player_name': 'Rubén Salv...
# 4    {'player_id': 6756, 'player_name': 'Marc Navar...
# 7    {'player_id': 6700, 'player_name': 'Sergio Enr...
# 9    {'player_id': 6297, 'player_name': 'Maximilian...
# ..                                                 ...
# 960  {'player_id': 5199, 'player_name': 'Jorge Resu...
# 963  {'player_id': 10277, 'player_name': 'Fabricio ...
# 964  {'player_id': 6565, 'player_name': 'Pere Pons ...
# 967  {'player_id': 6682, 'player_name': 'Sergio Pos...
# 969  {'player_id': 6705, 'player_name': 'José Ángel...
#
#                                               player_4  \
# 0    {'player_id': 6757, 'player_name': 'Aarón Mart...
# 2    {'player_id': 6600, 'player_name': 'Claudio Be...
# 4    {'player_id': 6757, 'player_name': 'Aarón Mart...
# 7    {'player_id': 6701, 'player_name': 'Joan Jordá...
# 9    {'player_id': 6794, 'player_name': 'Gustavo Da...
# ..                                                 ...
# 960  {'player_id': 5575, 'player_name': 'Héctor Mig...
# 963  {'player_id': 11671, 'player_name': 'Juan Cami...
# 964  {'player_id': 6612, 'player_name': 'Rubén Duar...
# 967  {'player_id': 6684, 'player_name': 'Roger Mart...
# 969  {'player_id': 6708, 'player_name': 'Paulo Andr...
#
#                                               player_5  \
# 0    {'player_id': 6758, 'player_name': 'Víctor Sán...
# 2    {'player_id': 6601, 'player_name': 'Raúl Garcí...
# 4    {'player_id': 6758, 'player_name': 'Víctor Sán...
# 7    {'player_id': 6702, 'player_name': 'David Rodr...
# 9    {'player_id': 6795, 'player_name': 'Rubén Blan...
# ..                                                 ...
# 960  {'player_id': 5696, 'player_name': 'Santiago A...
# 963  {'player_id': 23986, 'player_name': 'Aleix Feb...
# 964  {'player_id': 6615, 'player_name': 'Víctor Lag...
# 967  {'player_id': 6688, 'player_name': 'José Ángel...
# 969  {'player_id': 6709, 'player_name': 'Anaitz Arb...
#
#                                               player_6  \
# 0    {'player_id': 6761, 'player_name': 'Leonardo C...
# 2    {'player_id': 6602, 'player_name': 'Miguel Áng...
# 4    {'player_id': 6761, 'player_name': 'Leonardo C...
# 7    {'player_id': 6703, 'player_name': 'Christian ...
# 9    {'player_id': 6796, 'player_name': 'Nemanja Ra...
# ..                                                 ...
# 960  {'player_id': 6377, 'player_name': 'Ángel Mart...
# 963  {'player_id': 24067, 'player_name': 'Abdón Pra...
# 964  {'player_id': 6618, 'player_name': 'Martín Agu...
# 967  {'player_id': 6782, 'player_name': 'Enis Bardh...
# 969  {'player_id': 6712, 'player_name': 'Gonzalo Es...
#
#                                               player_7  \
# 0    {'player_id': 6763, 'player_name': 'Pablo Dani...
# 2    {'player_id': 6603, 'player_name': 'Dimitrios ...
# 4    {'player_id': 6766, 'player_name': 'Gerard Mor...
# 7    {'player_id': 6705, 'player_name': 'José Ángel...
# 9    {'player_id': 6797, 'player_name': 'Daniel Was...
# ..                                                 ...
# 960  {'player_id': 6378, 'player_name': 'Jan Oblak'...
# 963  {'player_id': 24072, 'player_name': 'Salvador ...
# 964  {'player_id': 6626, 'player_name': 'Mubarak Wa...
# 967  {'player_id': 6784, 'player_name': 'Antonio Ga...
# 969  {'player_id': 6867, 'player_name': 'Papa Kouly...
#
#                                               player_8  \
# 0    {'player_id': 6766, 'player_name': 'Gerard Mor...
# 2    {'player_id': 6604, 'player_name': 'Darko Braš...
# 4    {'player_id': 6767, 'player_name': 'Sergio Gar...
# 7    {'player_id': 6707, 'player_name': 'Charles Dí...
# 9    {'player_id': 6798, 'player_name': 'Stanislav ...
# ..                                                 ...
# 960  {'player_id': 6381, 'player_name': 'Saúl Ñígue...
# 963  {'player_id': 24083, 'player_name': 'Manuel Re...
# 964  {'player_id': 6629, 'player_name': 'Fernando P...
# 967  {'player_id': 11669, 'player_name': 'Gonzalo J...
# 969  {'player_id': 6907, 'player_name': 'Pedro León...
#
#                                               player_9  \
# 0    {'player_id': 6767, 'player_name': 'Sergio Gar...
# 2    {'player_id': 6605, 'player_name': 'Joseba Zal...
# 4    {'player_id': 6768, 'player_name': 'Diego Lópe...
# 7    {'player_id': 6708, 'player_name': 'Paulo Andr...
# 9    {'player_id': 6799, 'player_name': 'Brais Ménd...
# ..                                                 ...
# 960  {'player_id': 6383, 'player_name': 'Thomas Tey...
# 963  {'player_id': 24084, 'player_name': 'Martin Va...
# 964  {'player_id': 6632, 'player_name': 'Manuel Ale...
# 967  {'player_id': 11676, 'player_name': 'Jorge Mir...
# 969  {'player_id': 6910, 'player_name': 'Eduardo Ex...
#
#                                              player_10  \
# 0    {'player_id': 6768, 'player_name': 'Diego Lópe...
# 2    {'player_id': 6606, 'player_name': 'Javier Era...
# 4    {'player_id': 6769, 'player_name': 'Edinaldo G...
# 7    {'player_id': 6709, 'player_name': 'Anaitz Arb...
# 9    {'player_id': 6801, 'player_name': 'Pedro Pabl...
# ..                                                 ...
# 960  {'player_id': 6654, 'player_name': 'Antonio Ad...
# 963  {'player_id': 24086, 'player_name': 'Antonio J...
# 964  {'player_id': 6636, 'player_name': 'Rodrigo El...
# 967  {'player_id': 12020, 'player_name': 'Hernâni J...
# 969  {'player_id': 7105, 'player_name': 'Fabián Ari...
#
#                                              player_11  \
# 0    {'player_id': 6769, 'player_name': 'Edinaldo G...
# 2    {'player_id': 6607, 'player_name': 'Julián Oma...
# 4    {'player_id': 6770, 'player_name': 'Esteban Fé...
# 7    {'player_id': 6710, 'player_name': 'Rubén Peña...
# 9    {'player_id': 6803, 'player_name': 'Emre Mor',...
# ..                                                 ...
# 960  {'player_id': 6790, 'player_name': 'Mario Herm...
# 963  {'player_id': 24087, 'player_name': 'Iddrisu B...
# 964  {'player_id': 6732, 'player_name': 'Lucas Pére...
# 967  {'player_id': 17303, 'player_name': 'Nikola Vu...
# 969  {'player_id': 7154, 'player_name': 'Sebastián ...
#
#                                              player_12  \
# 0    {'player_id': 6790, 'player_name': 'Mario Herm...
# 2    {'player_id': 6608, 'player_name': 'Nabil El Z...
# 4    {'player_id': 6791, 'player_name': 'Javier Lóp...
# 7    {'player_id': 6712, 'player_name': 'Gonzalo Es...
# 9    {'player_id': 6804, 'player_name': 'Sergi Góme...
# ..                                                 ...
# 960  {'player_id': 6840, 'player_name': 'Marcos Llo...
# 963  {'player_id': 24088, 'player_name': 'Daniel Jo...
# 964  {'player_id': 6923, 'player_name': 'Joaquín Na...
# 967  {'player_id': 21147, 'player_name': 'Borja May...
# 969  {'player_id': 8555, 'player_name': 'Pablo Ezeq...
#
#                                              player_13  \
# 0    {'player_id': 6792, 'player_name': 'Pau López ...
# 2    {'player_id': 6610, 'player_name': 'Iván Cuéll...
# 4    {'player_id': 6870, 'player_name': 'José Manue...
# 7    {'player_id': 6775, 'player_name': 'Daniel Gar...
# 9    {'player_id': 6805, 'player_name': 'Hugo Mallo...
# ..                                                 ...
# 960  {'player_id': 6841, 'player_name': 'Víctor Mac...
# 963  {'player_id': 24089, 'player_name': 'Joan Sast...
# 964  {'player_id': 6935, 'player_name': 'Adrián Mar...
# 967  {'player_id': 23344, 'player_name': 'Aitor Fer...
# 969  {'player_id': 10612, 'player_name': 'Yoel Rodr...
#
#                                              player_14  \
# 0    {'player_id': 6866, 'player_name': 'Marc Roca ...
# 2    {'player_id': 6834, 'player_name': 'Gerard Gum...
# 4                                                  NaN
# 7    {'player_id': 6776, 'player_name': 'David Junc...
# 9    {'player_id': 6830, 'player_name': 'Facundo Se...
# ..                                                 ...
# 960  {'player_id': 11167, 'player_name': 'Felipe Au...
# 963  {'player_id': 24576, 'player_name': 'Francisco...
# 964  {'player_id': 9748, 'player_name': 'Antonio Si...
# 967                                                NaN
# 969  {'player_id': 13107, 'player_name': 'Sergio Ál...
#
#                                              player_15  \
# 0    {'player_id': 6867, 'player_name': 'Papa Kouly...
# 2    {'player_id': 6894, 'player_name': 'Ezequiel M...
# 4                                                  NaN
# 7    {'player_id': 6924, 'player_name': 'Alejandro ...
# 9    {'player_id': 6852, 'player_name': 'Jozabed Sá...
# ..                                                 ...
# 960  {'player_id': 12041, 'player_name': 'João Féli...
# 963  {'player_id': 25061, 'player_name': 'Francisco...
# 964  {'player_id': 24049, 'player_name': 'Luis Jesú...
# 967                                                NaN
# 969  {'player_id': 23803, 'player_name': 'Esteban R...
#
#                                              player_16  \
# 0    {'player_id': 6870, 'player_name': 'José Manue...
# 2    {'player_id': 6914, 'player_name': 'Roberto Ro...
# 4                                                  NaN
# 7    {'player_id': 7900, 'player_name': 'Tiago Manu...
# 9    {'player_id': 6884, 'player_name': 'Sergio Álv...
# ..                                                 ...
# 960  {'player_id': 26532, 'player_name': 'Renan Aug...
# 963  {'player_id': 27342, 'player_name': 'Josep Señ...
# 964  {'player_id': 24078, 'player_name': 'Javier Mu...
# 967                                                NaN
# 969  {'player_id': 23808, 'player_name': 'Enrique G...
#
#                                              player_17 player_18 player_19  \
# 0    {'player_id': 6886, 'player_name': 'Dídac Vilá...       NaN       NaN
# 2    {'player_id': 8642, 'player_name': 'Nereo Cham...       NaN       NaN
# 4                                                  NaN       NaN       NaN
# 7    {'player_id': 10763, 'player_name': 'Asier Rie...       NaN       NaN
# 9    {'player_id': 6890, 'player_name': 'Andreu Fon...       NaN       NaN
# ..                                                 ...       ...       ...
# 960  {'player_id': 34532, 'player_name': 'Ivan Šapo...       NaN       NaN
# 963  {'player_id': 31090, 'player_name': 'Takefusa ...       NaN       NaN
# 964  {'player_id': 30760, 'player_name': 'Borja Sai...       NaN       NaN
# 967                                                NaN       NaN       NaN
# 969  {'player_id': 23981, 'player_name': 'Álvaro Te...       NaN       NaN
#
#     player_20 player_21 player_22
# 0         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# 7         NaN       NaN       NaN
# 9         NaN       NaN       NaN
# ..        ...       ...       ...
# 960       NaN       NaN       NaN
# 963       NaN       NaN       NaN
# 964       NaN       NaN       NaN
# 967       NaN       NaN       NaN
# 969       NaN       NaN       NaN
#
# [485 rows x 23 columns]

# %%
lineups_barcelona = pd.concat([lineups_barcelona, split_player_barcelona], axis=1).drop(columns='lineup')
lineups_opposition = pd.concat([lineups_opposition, split_player_opposition], axis=1).drop(columns='lineup')

# %%
lineups_barcelona
# Out:
#      team_id  team_name  match_id season_name  \
# 1        217  Barcelona      9592   2017/2018
# 3        217  Barcelona      9870   2017/2018
# 5        217  Barcelona      9783   2017/2018
# 6        217  Barcelona      9609   2017/2018
# 8        217  Barcelona      9700   2017/2018
# ..       ...        ...       ...         ...
# 961      217  Barcelona    303524   2019/2020
# 962      217  Barcelona    303451   2019/2020
# 965      217  Barcelona    303517   2019/2020
# 966      217  Barcelona    303682   2019/2020
# 968      217  Barcelona    303731   2019/2020
#
#                                               player_0  \
# 1    {'player_id': 3726, 'player_name': 'Gerard Deu...
# 3    {'player_id': 3501, 'player_name': 'Philippe C...
# 5    {'player_id': 3501, 'player_name': 'Philippe C...
# 6    {'player_id': 3726, 'player_name': 'Gerard Deu...
# 8    {'player_id': 5203, 'player_name': 'Sergio Bus...
# ..                                                 ...
# 961  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 962  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 965  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 966  {'player_id': 5203, 'player_name': 'Sergio Bus...
# 968  {'player_id': 4447, 'player_name': 'Martin Bra...
#
#                                               player_1  \
# 1    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 3    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 5    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 6    {'player_id': 5203, 'player_name': 'Sergio Bus...
# 8    {'player_id': 5211, 'player_name': 'Jordi Alba...
# ..                                                 ...
# 961  {'player_id': 5246, 'player_name': 'Luis Alber...
# 962  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 965  {'player_id': 5211, 'player_name': 'Jordi Alba...
# 966  {'player_id': 5211, 'player_name': 'Jordi Alba...
# 968  {'player_id': 5203, 'player_name': 'Sergio Bus...
#
#                                               player_2  \
# 1    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 3    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 5    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 6    {'player_id': 5211, 'player_name': 'Jordi Alba...
# 8    {'player_id': 5213, 'player_name': 'Gerard Piq...
# ..                                                 ...
# 961  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 962  {'player_id': 5246, 'player_name': 'Luis Alber...
# 965  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 966  {'player_id': 5213, 'player_name': 'Gerard Piq...
# 968  {'player_id': 5213, 'player_name': 'Gerard Piq...
#
#                                               player_3  \
# 1    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 3    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 5    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 6    {'player_id': 5213, 'player_name': 'Gerard Piq...
# 8    {'player_id': 5216, 'player_name': 'Andrés Ini...
# ..                                                 ...
# 961  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 962  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 965  {'player_id': 5246, 'player_name': 'Luis Alber...
# 966  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 968  {'player_id': 5470, 'player_name': 'Ivan Rakit...
#
#                                               player_4  \
# 1    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 3    {'player_id': 5246, 'player_name': 'Luis Alber...
# 5    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 6    {'player_id': 5216, 'player_name': 'Andrés Ini...
# 8    {'player_id': 5246, 'player_name': 'Luis Alber...
# ..                                                 ...
# 961  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 962  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 965  {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 966  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 968  {'player_id': 5487, 'player_name': 'Antoine Gr...
#
#                                               player_5  \
# 1    {'player_id': 5246, 'player_name': 'Luis Alber...
# 3    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 5    {'player_id': 5246, 'player_name': 'Luis Alber...
# 6    {'player_id': 5246, 'player_name': 'Luis Alber...
# 8    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# ..                                                 ...
# 961  {'player_id': 5503, 'player_name': 'Lionel And...
# 962  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 965  {'player_id': 5487, 'player_name': 'Antoine Gr...
# 966  {'player_id': 5503, 'player_name': 'Lionel And...
# 968  {'player_id': 5492, 'player_name': 'Samuel Yve...
#
#                                               player_6  \
# 1    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 3    {'player_id': 5477, 'player_name': 'Ousmane De...
# 5    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 6    {'player_id': 5470, 'player_name': 'Ivan Rakit...
# 8    {'player_id': 5492, 'player_name': 'Samuel Yve...
# ..                                                 ...
# 961  {'player_id': 5674, 'player_name': 'Moussa Wag...
# 962  {'player_id': 5503, 'player_name': 'Lionel And...
# 965  {'player_id': 5492, 'player_name': 'Samuel Yve...
# 966  {'player_id': 6374, 'player_name': 'Nélson Cab...
# 968  {'player_id': 5503, 'player_name': 'Lionel And...
#
#                                               player_7  \
# 1    {'player_id': 5477, 'player_name': 'Ousmane De...
# 3    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 5    {'player_id': 5503, 'player_name': 'Lionel And...
# 6    {'player_id': 5503, 'player_name': 'Lionel And...
# 8    {'player_id': 5503, 'player_name': 'Lionel And...
# ..                                                 ...
# 961  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 962  {'player_id': 5674, 'player_name': 'Moussa Wag...
# 965  {'player_id': 5503, 'player_name': 'Lionel And...
# 966  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 968  {'player_id': 6374, 'player_name': 'Nélson Cab...
#
#                                               player_8  \
# 1    {'player_id': 5492, 'player_name': 'Samuel Yve...
# 3    {'player_id': 5503, 'player_name': 'Lionel And...
# 5    {'player_id': 5542, 'player_name': 'José Paulo...
# 6    {'player_id': 5506, 'player_name': 'Javier Ale...
# 8    {'player_id': 5542, 'player_name': 'José Paulo...
# ..                                                 ...
# 961  {'player_id': 6590, 'player_name': 'Norberto M...
# 962  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 965  {'player_id': 6374, 'player_name': 'Nélson Cab...
# 966  {'player_id': 6826, 'player_name': 'Clément Le...
# 968  {'player_id': 6379, 'player_name': 'Sergi Robe...
#
#                                               player_9  \
# 1    {'player_id': 5503, 'player_name': 'Lionel And...
# 3    {'player_id': 5542, 'player_name': 'José Paulo...
# 5    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 6    {'player_id': 5542, 'player_name': 'José Paulo...
# 8    {'player_id': 6332, 'player_name': 'Thomas Ver...
# ..                                                 ...
# 961  {'player_id': 6826, 'player_name': 'Clément Le...
# 962  {'player_id': 6590, 'player_name': 'Norberto M...
# 965  {'player_id': 6379, 'player_name': 'Sergi Robe...
# 966  {'player_id': 8118, 'player_name': 'Frenkie de...
# 968  {'player_id': 6590, 'player_name': 'Norberto M...
#
#                                              player_10  \
# 1    {'player_id': 5506, 'player_name': 'Javier Ale...
# 3    {'player_id': 6332, 'player_name': 'Thomas Ver...
# 5    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 6    {'player_id': 6332, 'player_name': 'Thomas Ver...
# 8    {'player_id': 6379, 'player_name': 'Sergi Robe...
# ..                                                 ...
# 961  {'player_id': 8118, 'player_name': 'Frenkie de...
# 962  {'player_id': 6826, 'player_name': 'Clément Le...
# 965  {'player_id': 6590, 'player_name': 'Norberto M...
# 966  {'player_id': 11392, 'player_name': 'Arthur He...
# 968  {'player_id': 6826, 'player_name': 'Clément Le...
#
#                                              player_11  \
# 1    {'player_id': 5542, 'player_name': 'José Paulo...
# 3    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 5    {'player_id': 6402, 'player_name': 'Francisco ...
# 6    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 8    {'player_id': 6400, 'player_name': 'Aleix Vida...
# ..                                                 ...
# 961  {'player_id': 8206, 'player_name': 'Arturo Era...
# 962  {'player_id': 8118, 'player_name': 'Frenkie de...
# 965  {'player_id': 6826, 'player_name': 'Clément Le...
# 966  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 968  {'player_id': 8118, 'player_name': 'Frenkie de...
#
#                                              player_12  \
# 1    {'player_id': 6374, 'player_name': 'Nélson Cab...
# 3    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 5    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 6    {'player_id': 6379, 'player_name': 'Sergi Robe...
# 8    {'player_id': 6402, 'player_name': 'Francisco ...
# ..                                                 ...
# 961  {'player_id': 11392, 'player_name': 'Arthur He...
# 962  {'player_id': 8206, 'player_name': 'Arturo Era...
# 965  {'player_id': 8118, 'player_name': 'Frenkie de...
# 966  {'player_id': 24841, 'player_name': 'Ricard Pu...
# 968  {'player_id': 8206, 'player_name': 'Arturo Era...
#
#                                              player_13  \
# 1    {'player_id': 6402, 'player_name': 'Francisco ...
# 3    {'player_id': 6402, 'player_name': 'Francisco ...
# 5    {'player_id': 20055, 'player_name': 'Marc-Andr...
# 6    {'player_id': 6400, 'player_name': 'Aleix Vida...
# 8    {'player_id': 6609, 'player_name': 'Denis Suár...
# ..                                                 ...
# 961  {'player_id': 13599, 'player_name': 'Carles Al...
# 962  {'player_id': 11532, 'player_name': 'Jean-Clai...
# 965  {'player_id': 8206, 'player_name': 'Arturo Era...
# 966  {'player_id': 30756, 'player_name': 'Anssumane...
# 968  {'player_id': 11392, 'player_name': 'Arthur He...
#
#                                              player_14  \
# 1    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 3    {'player_id': 6609, 'player_name': 'Denis Suár...
# 5                                                  NaN
# 6    {'player_id': 6609, 'player_name': 'Denis Suár...
# 8    {'player_id': 6849, 'player_name': 'Lucas Dign...
# ..                                                 ...
# 961  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 962  {'player_id': 13599, 'player_name': 'Carles Al...
# 965  {'player_id': 13599, 'player_name': 'Carles Al...
# 966                                                NaN
# 968  {'player_id': 17304, 'player_name': 'Héctor Ju...
#
#                                              player_15  \
# 1    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 3    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 5                                                  NaN
# 6    {'player_id': 6849, 'player_name': 'Lucas Dign...
# 8    {'player_id': 8652, 'player_name': 'Jasper Cil...
# ..                                                 ...
# 961  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 962  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 965  {'player_id': 17304, 'player_name': 'Héctor Ju...
# 966                                                NaN
# 968  {'player_id': 20055, 'player_name': 'Marc-Andr...
#
#                                              player_16  \
# 1    {'player_id': 10802, 'player_name': 'André Fil...
# 3    {'player_id': 10802, 'player_name': 'André Fil...
# 5                                                  NaN
# 6    {'player_id': 8652, 'player_name': 'Jasper Cil...
# 8    {'player_id': 10802, 'player_name': 'André Fil...
# ..                                                 ...
# 961  {'player_id': 25006, 'player_name': 'Carles Pé...
# 962  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 965  {'player_id': 20055, 'player_name': 'Marc-Andr...
# 966                                                NaN
# 968  {'player_id': 20734, 'player_name': 'Sergio Ak...
#
#                                              player_17 player_18 player_19  \
# 1    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 3    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 5                                                  NaN       NaN       NaN
# 6    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# 8    {'player_id': 20055, 'player_name': 'Marc-Andr...       NaN       NaN
# ..                                                 ...       ...       ...
# 961  {'player_id': 30756, 'player_name': 'Anssumane...       NaN       NaN
# 962  {'player_id': 25006, 'player_name': 'Carles Pé...       NaN       NaN
# 965  {'player_id': 25006, 'player_name': 'Carles Pé...       NaN       NaN
# 966                                                NaN       NaN       NaN
# 968  {'player_id': 30756, 'player_name': 'Anssumane...       NaN       NaN
#
#     player_20 player_21 player_22
# 1         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 5         NaN       NaN       NaN
# 6         NaN       NaN       NaN
# 8         NaN       NaN       NaN
# ..        ...       ...       ...
# 961       NaN       NaN       NaN
# 962       NaN       NaN       NaN
# 965       NaN       NaN       NaN
# 966       NaN       NaN       NaN
# 968       NaN       NaN       NaN
#
# [485 rows x 27 columns]

# %% [markdown]
# # Export created dataframes to CSV...

# %%
selected_competitions = selected_competitions.to_csv('../data/cleaned-data/competitions.csv', index=False)

# %%
la_liga_matches = la_liga_matches.to_csv('../data/cleaned-data/la_liga_matches.csv', index=False)

# %%
events = events.to_csv('../data/cleaned-data/events.csv', index=False)

# %%
lineups_barcelona = lineups_barcelona.to_csv('../data/cleaned-data/lineups_barcelona.csv', index=False)

# %%
lineups_opposition = lineups_opposition.to_csv('../data/cleaned-data/lineups_opposition.csv', index=False)
