# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('../data/cleaned-data/messi_involvement_matches.csv')

# %%
test
# Out:
#      const  match_id season_name  match_week  match_date kick_off  \
# 0      1.0     68353   2004/2005           7  2004-10-16    22:00
# 1      1.0     68313   2004/2005           8  2004-10-24    21:00
# 2      1.0     68314   2004/2005          14  2004-12-04    20:00
# 3      1.0     69153   2004/2005          15  2004-12-11    20:00
# 4      1.0     68315   2004/2005          17  2004-12-21    20:00
# ..     ...       ...         ...         ...         ...      ...
# 480    1.0    303725   2019/2020          34  2020-07-05    22:00
# 481    1.0    303615   2019/2020          35  2020-07-08    22:00
# 482    1.0    303680   2019/2020          36  2020-07-11    19:30
# 483    1.0    303634   2019/2020          37  2020-07-16    21:00
# 484    1.0    303421   2019/2020          38  2020-07-19    17:00
#
#                         stadium_name                 referee_name  \
# 0      Estadi Olímpic Lluís Companys          Carlos Megía Dávila
# ...

# %%
test['involvements'] = test['goals'] + test['assists']

# %%
test.groupby('opposition').sum().sort_values('goals')
# Out:
#                      const   match_id  match_week  match_points  \
# opposition
# Xerez                  2.0   138481.0        49.0           6.0
# Real Murcia            1.0    69186.0        38.0           3.0
# Cádiz                  1.0    68322.0        16.0           3.0
# Albacete               2.0   137469.0        49.0           6.0
# Gimnàstic Tarragona    1.0    68336.0        38.0           3.0
# Numancia               2.0   138336.0        21.0           3.0
# Huesca                 1.0    15973.0         3.0           3.0
# Hércules               2.0   138583.0        23.0           3.0
# Recreativo Huelva      5.0   344390.0       113.0          13.0
# Córdoba                2.0   532712.0        51.0           6.0
# Elche                  3.0   799916.0        58.0           7.0
# Girona                 4.0    51566.0        57.0          10.0
# Las Palmas             6.0  1088781.0       119.0          16.0
# ...
